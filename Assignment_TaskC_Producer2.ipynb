# %% [markdown]
#  # Event Producer 2:
# This is a program that loads all the data from hotspot_AQUA_streaming.csv and randomly feed the data to the stream
# every 10 - 30 seconds. AQUA is the satellite from NASA that reports latitude, longitude, confidence and surface temperature of a location. I have also appended additional information such as sender_id and created_time.

# %%
import csv 
import json

hotspot_aqua_streaming=[]

with open("hotspot_AQUA_streaming.csv",'r') as hotspot_aqua_infile:
    hotspot_reader=csv.DictReader(hotspot_aqua_infile)
    ids=1000000
    for row in hotspot_reader:
        temp_dict=row
        temp_dict["sender_id"]=2
        ids+=1
        temp_dict["_id"]=ids
        hotspot_aqua_streaming.append(temp_dict)
        
# climate_historic
        

#https://www.pythonforbeginners.com/csv/using-the-csv-module-in-python

# %%
# import statements

from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt


def publish_message(producer_instance, topic_name, key, data):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=data)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['127.0.0.1:9092'],
                                  value_serializer=lambda x:dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    

    
if __name__ == '__main__':
   
    topic = 'climate_data'
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    while hotspot_aqua_streaming:
        elem= random.randint(0,len(hotspot_aqua_streaming)-1)
        temp_dict={}
        temp_dict=hotspot_aqua_streaming.pop(elem)
        temp_dict['timestamp']=str(dt.datetime.now())     
        data=temp_dict
        publish_message(producer, topic, 'jsondata',data)
        time_delay=random.randint(10,30)
        sleep(time_delay)
# Out:
# Publishing records..
# Message published successfully. Data: {'confidence': '64', 'timestamp': '2019-05-24 21:16:40.577496', 'latitude': '-36.309', 'surface_temperature_celcius': '42', '_id': 1001142, 'longitude': '145.6878', 'sender_id': 2}
# Message published successfully. Data: {'confidence': '81', 'timestamp': '2019-05-24 21:16:56.600491', 'latitude': '-37.1405', 'surface_temperature_celcius': '54', '_id': 1000330, 'longitude': '144.1375', 'sender_id': 2}
# Message published successfully. Data: {'confidence': '57', 'timestamp': '2019-05-24 21:17:25.639108', 'latitude': '-37.6345', 'surface_temperature_celcius': '39', '_id': 1001343, 'longitude': '143.1335', 'sender_id': 2}
# Message published successfully. Data: {'confidence': '58', 'timestamp': '2019-05-24 21:17:46.668638', 'latitude': '-37.9408', 'surface_temperature_celcius': '47', '_id': 1002075, 'longitude': '146.0611', 'sender_id': 2}
# ...
