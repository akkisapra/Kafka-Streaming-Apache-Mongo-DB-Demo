# %% [markdown]
# # FIT 5148 - Distributed Databases and Big Data Assignment 2

# %% [markdown]
# ### Task A. MongoDB Data Model

# %% [markdown]
# We had to use 2 data set to decide on to the data model, which are:
# >* hotspot_historic.csv (2668 rows)
# >* climate_historic.csv (366 rows)
#
# After Exploring through the data set it can be noticed that:
# >- Dates are unique in climate data.
# >- Datasets can be mapped through date column in both the datasets.
# >- Cardinality of the dataset is 1 to N.
# >- Datasets cardinality justify either of "one to few" or "one to many" relation where on an average one row of climate data gets mapped to 10 rows of hotspot data (in this case there are ~100 rows with no data mapped to historic which further increase the count of mapping).
# >- If the relation is "one to few" we use Embedded nodel and if the relationship is "one to many" we prefer reference model (Less than 1000),
#
# It is a little ambigous situation where both the model will work fine. For Instance, If Embeded model is used perfomance of the query will be better as it will not have to query separate collection. But in this instance the primary focus of the task is to investigate on fire incidents and there might be a possibility that we might need to query the hotspot data which might make it  hard to access the details as stand-alone entities.
#
# Therefore, in this case, we have decided to use the **reference model**. It will also ensure that searching and fetching of independent entities can be done easily and quickly. To make the referencing simple we will introduce an integer object id which will act as reference to the _id of the hotspot data.
#
# We have also incorporated **two way referencing** to reference from hotspot data to climate data to cater to the possible need of identifying a fire to particular sensor.
#
# To enhance the perfomance of our model we have also incorporated **Denormalization** of "surface_temperature_celcius" and "confidence" from historic data to climate data under the assumption that it is analysis task and there will high read to write ratio and no Update will be required to the dataset.(which is one of the major disadvantage of denormalization).
#
#
# Below is the example of our model

# %% [markdown]
# **Climate Data**
#
# ```
# [
#  {
#    " _id": '123'
#     "station": '948702',
#     "date": '27/12/2017',
#     "air_temperature_celcius": '28'
#     "relative_humidity": '58.3'
#     "windspeed_knots": '9.3'
#     "max_wind_speed": '15.9'
#     "precipitation": '0.00I'
#
#     "hotspot": [
#         { "id": '10001', "confidence":"78", "surface_temperature_celcius":"68"},
#         { "id": '10002', "confidence":"82", "surface_temperature_celcius":"63"},
#         { "id": '10003', "confidence":"67", "surface_temperature_celcius":"53"},
#         { "id": '10004', "confidence":"86", "surface_temperature_celcius":"67"}
#     ]
#  }
# ]
# ```
#
#
#  **Hotspot Data**
# ```
#  [
#      {
#         "_id": '10001'
#         "latitude": '-37.966'
#         "longitude": '145.051'
#         "datetime": '2017-12-27T04:16:51'
#         "confidence": '78'
#         "date":'27/12/2017'
#         "surface_temperature_celcius": '68'
#         "owner": "123"
#         },
#
#      {
#         "_id": '10002'
#         "latitude": '-35.541'
#         "longitude": '143.311'
#         "datetime": '2017-12-27T00:02:15'
#         "confidence": '82'
#         "date": '27/12/2017'
#         "surface_temperature_celcius": '63'
#         "owner": "123"
#         }
# ]
#
# ```

# %% [markdown]
# Loading the Climate historic file into dictionary

# %%
import csv 
import json

climate_historic=[]

with open("climate_historic.csv",'r') as climate_infile:
    climate_reader=csv.DictReader(climate_infile)
    id_climate=100
    for row in climate_reader:
        id_climate+=1
        temp_dict=row
        temp_dict["_id"]=id_climate
        climate_historic.append(temp_dict)
        
# climate_historic
        

#https://www.pythonforbeginners.com/csv/using-the-csv-module-in-python

# %% [markdown]
# Loading the Hotspot historic file into dictionary

# %%
hotspot_historic=[]

with open("hotspot_historic.csv",'r') as hotspot_infile:
    hotspot_reader=csv.DictReader(hotspot_infile)
    id_hotspot=10000
    for row in hotspot_reader:
        id_hotspot+=1
        temp_dict=row
        temp_dict["_id"]=id_hotspot
        hotspot_historic.append(temp_dict)

# hotspot_historic

# %%
final_hotspot=[]
final_climate=[]

for each_climate in climate_historic:
    each_climate['hotspot']=[]
    for each_hotspot in hotspot_historic:
        if each_climate["date"]== each_hotspot["date"]:
            temp_dict={}
            temp_dict["_id"]=each_hotspot["_id"]
            temp_dict["confidence"]=each_hotspot["confidence"]
            temp_dict["surface_temperature_celcius"]=each_hotspot["surface_temperature_celcius"]
            each_climate["hotspot"].append(temp_dict)
    final_climate.append(each_climate)
    


for each_hotspot in hotspot_historic:
    each_hotspot['surface_temperature_celcius']=int(each_hotspot['surface_temperature_celcius'])
    each_hotspot['confidence']=int(each_hotspot['confidence'])
    for each_climate in climate_historic:
        if each_climate["date"]== each_hotspot["date"]:
            each_hotspot['owner']=each_climate['_id']
    final_hotspot.append(each_hotspot)

# %% [markdown]
# Inserting rows into Mongo DB

# %%
import pymongo
from pymongo import MongoClient

## creating connection to Mongo db

# Method 1: connect on the default host and port
client = MongoClient () # method 1: connect on the default host and port

client.drop_database('fit5148_assignment_db')
db=client['fit5148_assignment_db']
db['hotspot_historic'].insert_many(final_hotspot)
db['climate_historic'].insert_many(final_climate)
#way of getting a collection
# db.hotspot.insert_many(final_hotspot)

# %% [markdown]
# ###### Creating Index

# %%
db['climate_historic'].create_index([('date', pymongo.ASCENDING)], unique=True)
db['hotspot_historic'].create_index([('date', pymongo.ASCENDING)])
# Out:
# 'date_1'

# %%
sorted(list(db['hotspot_historic'].index_information()))
sorted(list(db['climate_historic'].index_information()))
# Out:
# ['_id_', 'date_1']

# %% [markdown]
# ###### Task a:  climate data on 10th December 2017.

# %%
from pprint import pprint

result=db['climate_historic'].find({"date":"10/12/2017"})
# cursor = montours.find({})
for document in result: 
    pprint(document)
# Out:
# {'_id': 444,
#  'air_temperature_celcius': '17',
#  'date': '10/12/2017',
#  'hotspot': [{'_id': 10030,
#               'confidence': '50',
#               'surface_temperature_celcius': '38'},
#              {'_id': 10031,
#               'confidence': '67',
#               'surface_temperature_celcius': '54'}],
#  'max_wind_speed': '14',
#  'precipitation ': ' 0.00I',
#  'relative_humidity': '53.5',
#  'station': '948702',
#  'windspeed_knots': '7.3'}

# %% [markdown]
# ###### Task b : latitude, longitude, surface temperature (°C), and confidence when the surface temperature (°C) was between 65 °C and 100 °C.

# %%
result=db['hotspot_historic'].find({"surface_temperature_celcius":{"$gte":65,"$lte":100}},{"latitude":1,"longitude":1 ,"surface_temperature_celcius":1,"confidence":1})
                                                           
for document in result: 
    pprint(document)
# Out:
# {'_id': 10001,
#  'confidence': 78,
#  'latitude': '-37.966',
#  'longitude': '145.051',
#  'surface_temperature_celcius': 68}
# {'_id': 10004,
#  'confidence': 86,
#  'latitude': '-35.543',
#  'longitude': '143.316',
#  'surface_temperature_celcius': 67}
# {'_id': 10011,
#  'confidence': 93,
#  'latitude': '-37.875',
#  'longitude': '142.51',
#  'surface_temperature_celcius': 73}
# {'_id': 10013,
#  'confidence': 95,
#  'latitude': '-37.613',
#  'longitude': '149.305',
#  'surface_temperature_celcius': 75}
# {'_id': 10015,
#  'confidence': 90,
#  'latitude': '-37.624',
#  'longitude': '149.314',
#  'surface_temperature_celcius': 66}
# {'_id': 10018,
#  'confidence': 93,
#  'latitude': '-38.057',
#  'longitude': '144.211',
#  'surface_temperature_celcius': 73}
# {'_id': 10027,
#  'confidence': 92,
#  'latitude': '-37.95',
#  'longitude': '142.366',
#  'surface_temperature_celcius': 70}
# {'_id': 10038,
#  'confidence': 100,
#  'latitude': '-36.282',
#  'longitude': '146.157',
#  'surface_temperature_celcius': 71}
# {'_id': 10054,
#  'confidence': 100,
#  'latitude': '-37.642',
#  'longitude': '149.263',
#  'surface_temperature_celcius': 65}
# {'_id': 10055,
#  'confidence': 100,
#  'latitude': '-37.634',
#  'longitude': '149.237',
#  'surface_temperature_celcius': 71}
# {'_id': 10058,
#  'confidence': 98,
#  'latitude': '-37.605',
#  'longitude': '149.302',
#  'surface_temperature_celcius': 83}
# {'_id': 10061,
#  'confidence': 99,
#  'latitude': '-37.6',
#  'longitude': '149.325',
#  'surface_temperature_celcius': 86}
# {'_id': 10066,
#  'confidence': 95,
#  'latitude': '-37.618',
#  'longitude': '149.281',
#  'surface_temperature_celcius': 76}
# {'_id': 10076,
#  'confidence': 100,
#  'latitude': '-37.606',
#  'longitude': '149.312',
#  'surface_temperature_celcius': 87}
# {'_id': 10078,
#  'confidence': 97,
#  'latitude': '-37.61',
#  'longitude': '149.307',
#  'surface_temperature_celcius': 80}
# {'_id': 10079,
#  'confidence': 99,
#  'latitude': '-37.609',
#  'longitude': '149.32',
#  'surface_temperature_celcius': 84}
# {'_id': 10082,
#  'confidence': 93,
#  'latitude': '-37.945',
#  'longitude': '144.354',
#  'surface_temperature_celcius': 73}
# {'_id': 10089,
#  'confidence': 87,
#  'latitude': '-37.862',
#  'longitude': '144.175',
#  'surface_temperature_celcius': 65}
# {'_id': 10101,
#  'confidence': 89,
#  'latitude': '-36.94',
#  'longitude': '143.281',
#  'surface_temperature_celcius': 69}
# {'_id': 10111,
#  'confidence': 100,
#  'latitude': '-37.477',
#  'longitude': '143.352',
#  'surface_temperature_celcius': 93}
# {'_id': 10112,
#  'confidence': 96,
#  'latitude': '-37.475',
#  'longitude': '143.365',
#  'surface_temperature_celcius': 77}
# {'_id': 10115,
#  'confidence': 97,
#  'latitude': '-37.69',
#  'longitude': '143.605',
#  'surface_temperature_celcius': 80}
# {'_id': 10120,
#  'confidence': 90,
#  'latitude': '-37.331',
#  'longitude': '143.122',
#  'surface_temperature_celcius': 65}
# {'_id': 10137,
#  'confidence': 92,
#  'latitude': '-36.098',
#  'longitude': '143.74',
#  'surface_temperature_celcius': 67}
# {'_id': 10149,
#  'confidence': 91,
#  'latitude': '-37.247',
#  'longitude': '141.278',
#  'surface_temperature_celcius': 68}
# {'_id': 10153,
#  'confidence': 100,
#  'latitude': '-37.294',
#  'longitude': '141.232',
#  'surface_temperature_celcius': 87}
# {'_id': 10154,
#  'confidence': 99,
#  'latitude': '-37.293',
#  'longitude': '141.245',
#  'surface_temperature_celcius': 85}
# {'_id': 10157,
#  'confidence': 96,
#  'latitude': '-38.127',
#  'longitude': '143.82',
#  'surface_temperature_celcius': 77}
# {'_id': 10182,
#  'confidence': 100,
#  'latitude': '-37.462',
#  'longitude': '148.089',
#  'surface_temperature_celcius': 90}
# {'_id': 10183,
#  'confidence': 88,
#  'latitude': '-37.46',
#  'longitude': '148.102',
#  'surface_temperature_celcius': 65}
# {'_id': 10214,
#  'confidence': 100,
#  'latitude': '-37.446',
#  'longitude': '148.102',
#  'surface_temperature_celcius': 65}
# {'_id': 10229,
#  'confidence': 100,
#  'latitude': '-37.406',
#  'longitude': '148.123',
#  'surface_temperature_celcius': 88}
# {'_id': 10231,
#  'confidence': 68,
#  'latitude': '-37.452',
#  'longitude': '148.115',
#  'surface_temperature_celcius': 77}
# {'_id': 10233,
#  'confidence': 64,
#  'latitude': '-37.45',
#  'longitude': '148.126',
#  'surface_temperature_celcius': 69}
# {'_id': 10234,
#  'confidence': 86,
#  'latitude': '-37.436',
#  'longitude': '148.088',
#  'surface_temperature_celcius': 76}
# {'_id': 10235,
#  'confidence': 73,
#  'latitude': '-37.444',
#  'longitude': '148.101',
#  'surface_temperature_celcius': 66}
# {'_id': 10236,
#  'confidence': 61,
#  'latitude': '-37.562',
#  'longitude': '148.05',
#  'surface_temperature_celcius': 72}
# {'_id': 10243,
#  'confidence': 58,
#  'latitude': '-37.379',
#  'longitude': '148.126',
#  'surface_temperature_celcius': 82}
# {'_id': 10244,
#  'confidence': 62,
#  'latitude': '-37.379',
#  'longitude': '148.132',
#  'surface_temperature_celcius': 78}
# {'_id': 10246,
#  'confidence': 100,
#  'latitude': '-37.396',
#  'longitude': '148.086',
#  'surface_temperature_celcius': 65}
# {'_id': 10251,
#  'confidence': 100,
#  'latitude': '-37.399',
#  'longitude': '148.081',
#  'surface_temperature_celcius': 84}
# {'_id': 10252,
#  'confidence': 100,
#  'latitude': '-37.401',
#  'longitude': '148.067',
#  'surface_temperature_celcius': 79}
# {'_id': 10291,
#  'confidence': 94,
#  'latitude': '-37.4796',
#  'longitude': '141.9403',
#  'surface_temperature_celcius': 87}
# {'_id': 10293,
#  'confidence': 89,
#  'latitude': '-38.3998',
#  'longitude': '147.064',
#  'surface_temperature_celcius': 65}
# {'_id': 10302,
#  'confidence': 91,
#  'latitude': '-37.8644',
#  'longitude': '143.4263',
#  'surface_temperature_celcius': 69}
# {'_id': 10327,
#  'confidence': 91,
#  'latitude': '-36.3774',
#  'longitude': '143.7079',
#  'surface_temperature_celcius': 68}
# {'_id': 10328,
#  'confidence': 100,
#  'latitude': '-36.3756',
#  'longitude': '143.7243',
#  'surface_temperature_celcius': 88}
# {'_id': 10329,
#  'confidence': 97,
#  'latitude': '-36.369',
#  'longitude': '143.7132',
#  'surface_temperature_celcius': 80}
# {'_id': 10330,
#  'confidence': 100,
#  'latitude': '-36.3799',
#  'longitude': '143.7149',
#  'surface_temperature_celcius': 89}
# {'_id': 10336,
#  'confidence': 94,
#  'latitude': '-36.2693',
#  'longitude': '143.1768',
#  'surface_temperature_celcius': 85}
# {'_id': 10350,
#  'confidence': 96,
#  'latitude': '-36.1002',
#  'longitude': '142.3405',
#  'surface_temperature_celcius': 78}
# {'_id': 10358,
#  'confidence': 90,
#  'latitude': '-36.4325',
#  'longitude': '144.3142',
#  'surface_temperature_celcius': 67}
# {'_id': 10361,
#  'confidence': 91,
#  'latitude': '-36.7685',
#  'longitude': '142.7134',
#  'surface_temperature_celcius': 69}
# {'_id': 10364,
#  'confidence': 91,
#  'latitude': '-36.7801',
#  'longitude': '142.7151',
#  'surface_temperature_celcius': 68}
# {'_id': 10412,
#  'confidence': 91,
#  'latitude': '-36.7746',
#  'longitude': '146.6642',
#  'surface_temperature_celcius': 68}
# {'_id': 10414,
#  'confidence': 96,
#  'latitude': '-36.8359',
#  'longitude': '146.6448',
#  'surface_temperature_celcius': 78}
# {'_id': 10417,
#  'confidence': 98,
#  'latitude': '-37.9085',
#  'longitude': '141.1038',
#  'surface_temperature_celcius': 82}
# {'_id': 10420,
#  'confidence': 100,
#  'latitude': '-38.4349',
#  'longitude': '146.3122',
#  'surface_temperature_celcius': 93}
# {'_id': 10421,
#  'confidence': 89,
#  'latitude': '-38.4792',
#  'longitude': '146.3081',
#  'surface_temperature_celcius': 65}
# {'_id': 10426,
#  'confidence': 100,
#  'latitude': '-37.9047',
#  'longitude': '141.0945',
#  'surface_temperature_celcius': 90}
# {'_id': 10442,
#  'confidence': 93,
#  'latitude': '-37.4984',
#  'longitude': '142.9739',
#  'surface_temperature_celcius': 73}
# {'_id': 10443,
#  'confidence': 96,
#  'latitude': '-37.253',
#  'longitude': '144.3681',
#  'surface_temperature_celcius': 78}
# {'_id': 10448,
#  'confidence': 92,
#  'latitude': '-36.9396',
#  'longitude': '143.1462',
#  'surface_temperature_celcius': 70}
# {'_id': 10455,
#  'confidence': 96,
#  'latitude': '-36.3387',
#  'longitude': '141.7542',
#  'surface_temperature_celcius': 77}
# {'_id': 10469,
#  'confidence': 100,
#  'latitude': '-36.3433',
#  'longitude': '143.4369',
#  'surface_temperature_celcius': 94}
# {'_id': 10473,
#  'confidence': 100,
#  'latitude': '-36.345',
#  'longitude': '143.4256',
#  'surface_temperature_celcius': 87}
# {'_id': 10474,
#  'confidence': 90,
#  'latitude': '-36.7032',
#  'longitude': '144.0992',
#  'surface_temperature_celcius': 66}
# {'_id': 10489,
#  'confidence': 96,
#  'latitude': '-36.3402',
#  'longitude': '141.7429',
#  'surface_temperature_celcius': 77}
# {'_id': 10494,
#  'confidence': 89,
#  'latitude': '-36.5661',
#  'longitude': '142.2956',
#  'surface_temperature_celcius': 65}
# {'_id': 10506,
#  'confidence': 85,
#  'latitude': '-36.5023',
#  'longitude': '143.6038',
#  'surface_temperature_celcius': 66}
# {'_id': 10508,
#  'confidence': 90,
#  'latitude': '-36.8616',
#  'longitude': '142.8025',
#  'surface_temperature_celcius': 78}
# {'_id': 10520,
#  'confidence': 90,
#  'latitude': '-38.0372',
#  'longitude': '146.0616',
#  'surface_temperature_celcius': 67}
# {'_id': 10521,
#  'confidence': 94,
#  'latitude': '-38.049',
#  'longitude': '146.0513',
#  'surface_temperature_celcius': 74}
# {'_id': 10524,
#  'confidence': 89,
#  'latitude': '-35.4666',
#  'longitude': '142.0749',
#  'surface_temperature_celcius': 65}
# {'_id': 10527,
#  'confidence': 95,
#  'latitude': '-36.0396',
#  'longitude': '141.7183',
#  'surface_temperature_celcius': 76}
# {'_id': 10532,
#  'confidence': 94,
#  'latitude': '-36.2775',
#  'longitude': '146.1026',
#  'surface_temperature_celcius': 74}
# {'_id': 10539,
#  'confidence': 100,
#  'latitude': '-38.0361',
#  'longitude': '146.0567',
#  'surface_temperature_celcius': 90}
# {'_id': 10544,
#  'confidence': 95,
#  'latitude': '-36.3254',
#  'longitude': '144.3638',
#  'surface_temperature_celcius': 77}
# {'_id': 10549,
#  'confidence': 100,
#  'latitude': '-36.0816',
#  'longitude': '145.859',
#  'surface_temperature_celcius': 98}
# {'_id': 10553,
#  'confidence': 100,
#  'latitude': '-36.1532',
#  'longitude': '143.5527',
#  'surface_temperature_celcius': 90}
# {'_id': 10561,
#  'confidence': 100,
#  'latitude': '-36.0077',
#  'longitude': '141.7747',
#  'surface_temperature_celcius': 93}
# {'_id': 10573,
#  'confidence': 94,
#  'latitude': '-36.0828',
#  'longitude': '145.873',
#  'surface_temperature_celcius': 75}
# {'_id': 10580,
#  'confidence': 91,
#  'latitude': '-36.5541',
#  'longitude': '144.1321',
#  'surface_temperature_celcius': 69}
# {'_id': 10583,
#  'confidence': 91,
#  'latitude': '-35.6819',
#  'longitude': '143.5275',
#  'surface_temperature_celcius': 69}
# {'_id': 10586,
#  'confidence': 90,
#  'latitude': '-35.6871',
#  'longitude': '143.5235',
#  'surface_temperature_celcius': 68}
# {'_id': 10591,
#  'confidence': 100,
#  'latitude': '-36.1506',
#  'longitude': '143.5671',
#  'surface_temperature_celcius': 95}
# {'_id': 10600,
#  'confidence': 93,
#  'latitude': '-37.4671',
#  'longitude': '145.9962',
#  'surface_temperature_celcius': 73}
# {'_id': 10606,
#  'confidence': 90,
#  'latitude': '-36.2911',
#  'longitude': '141.1664',
#  'surface_temperature_celcius': 67}
# {'_id': 10607,
#  'confidence': 96,
#  'latitude': '-36.2842',
#  'longitude': '141.1741',
#  'surface_temperature_celcius': 79}
# {'_id': 10609,
#  'confidence': 89,
#  'latitude': '-36.7218',
#  'longitude': '141.6411',
#  'surface_temperature_celcius': 65}
# {'_id': 10610,
#  'confidence': 84,
#  'latitude': '-37.3656',
#  'longitude': '141.3903',
#  'surface_temperature_celcius': 78}
# {'_id': 10612,
#  'confidence': 94,
#  'latitude': '-36.4179',
#  'longitude': '144.2924',
#  'surface_temperature_celcius': 75}
# {'_id': 10614,
#  'confidence': 92,
#  'latitude': '-36.3207',
#  'longitude': '140.9737',
#  'surface_temperature_celcius': 70}
# {'_id': 10617,
#  'confidence': 99,
#  'latitude': '-36.2882',
#  'longitude': '141.1821',
#  'surface_temperature_celcius': 86}
# {'_id': 10618,
#  'confidence': 91,
#  'latitude': '-36.3153',
#  'longitude': '140.9789',
#  'surface_temperature_celcius': 69}
# {'_id': 10620,
#  'confidence': 97,
#  'latitude': '-36.4169',
#  'longitude': '144.2994',
#  'surface_temperature_celcius': 81}
# {'_id': 10625,
#  'confidence': 96,
#  'latitude': '-36.8094',
#  'longitude': '142.8885',
#  'surface_temperature_celcius': 77}
# {'_id': 10641,
#  'confidence': 84,
#  'latitude': '-37.8323',
#  'longitude': '147.2232',
#  'surface_temperature_celcius': 68}
# {'_id': 10657,
#  'confidence': 98,
#  'latitude': '-38.2853',
#  'longitude': '145.9519',
#  'surface_temperature_celcius': 83}
# {'_id': 10658,
#  'confidence': 98,
#  'latitude': '-38.2375',
#  'longitude': '142.8363',
#  'surface_temperature_celcius': 82}
# {'_id': 10660,
#  'confidence': 92,
#  'latitude': '-37.4463',
#  'longitude': '142.7829',
#  'surface_temperature_celcius': 70}
# {'_id': 10671,
#  'confidence': 95,
#  'latitude': '-37.6854',
#  'longitude': '143.4543',
#  'surface_temperature_celcius': 76}
# {'_id': 10677,
#  'confidence': 99,
#  'latitude': '-38.0881',
#  'longitude': '143.9391',
#  'surface_temperature_celcius': 84}
# {'_id': 10678,
#  'confidence': 96,
#  'latitude': '-38.0866',
#  'longitude': '143.9534',
#  'surface_temperature_celcius': 78}
# {'_id': 10679,
#  'confidence': 92,
#  'latitude': '-38.2391',
#  'longitude': '142.82',
#  'surface_temperature_celcius': 71}
# {'_id': 10682,
#  'confidence': 100,
#  'latitude': '-38.5123',
#  'longitude': '146.4007',
#  'surface_temperature_celcius': 89}
# {'_id': 10711,
#  'confidence': 96,
#  'latitude': '-36.3438',
#  'longitude': '141.5832',
#  'surface_temperature_celcius': 78}
# {'_id': 10718,
#  'confidence': 94,
#  'latitude': '-37.4357',
#  'longitude': '142.7813',
#  'surface_temperature_celcius': 74}
# {'_id': 10738,
#  'confidence': 99,
#  'latitude': '-37.5867',
#  'longitude': '143.6256',
#  'surface_temperature_celcius': 85}
# {'_id': 10753,
#  'confidence': 93,
#  'latitude': '-36.2306',
#  'longitude': '143.6408',
#  'surface_temperature_celcius': 72}
# {'_id': 10763,
#  'confidence': 91,
#  'latitude': '-36.4168',
#  'longitude': '141.6939',
#  'surface_temperature_celcius': 68}
# {'_id': 10774,
#  'confidence': 97,
#  'latitude': '-36.4211',
#  'longitude': '141.6875',
#  'surface_temperature_celcius': 81}
# {'_id': 10782,
#  'confidence': 91,
#  'latitude': '-35.6138',
#  'longitude': '143.8666',
#  'surface_temperature_celcius': 68}
# {'_id': 10785,
#  'confidence': 95,
#  'latitude': '-36.0885',
#  'longitude': '145.0359',
#  'surface_temperature_celcius': 76}
# {'_id': 10786,
#  'confidence': 96,
#  'latitude': '-36.3193',
#  'longitude': '145.9162',
#  'surface_temperature_celcius': 78}
# {'_id': 10788,
#  'confidence': 98,
#  'latitude': '-36.0652',
#  'longitude': '146.0764',
#  'surface_temperature_celcius': 82}
# {'_id': 10790,
#  'confidence': 100,
#  'latitude': '-36.0682',
#  'longitude': '146.0602',
#  'surface_temperature_celcius': 90}
# {'_id': 10794,
#  'confidence': 92,
#  'latitude': '-37.7889',
#  'longitude': '143.1324',
#  'surface_temperature_celcius': 71}
# {'_id': 10796,
#  'confidence': 95,
#  'latitude': '-36.6139',
#  'longitude': '143.501',
#  'surface_temperature_celcius': 77}
# {'_id': 10802,
#  'confidence': 95,
#  'latitude': '-37.9509',
#  'longitude': '143.9599',
#  'surface_temperature_celcius': 76}
# {'_id': 10815,
#  'confidence': 97,
#  'latitude': '-36.6224',
#  'longitude': '143.5092',
#  'surface_temperature_celcius': 80}
# {'_id': 10825,
#  'confidence': 96,
#  'latitude': '-38.0933',
#  'longitude': '143.9824',
#  'surface_temperature_celcius': 78}
# {'_id': 10827,
#  'confidence': 92,
#  'latitude': '-36.663',
#  'longitude': '142.8567',
#  'surface_temperature_celcius': 71}
# {'_id': 10837,
#  'confidence': 94,
#  'latitude': '-37.6982',
#  'longitude': '143.0549',
#  'surface_temperature_celcius': 73}
# {'_id': 10840,
#  'confidence': 95,
#  'latitude': '-36.7187',
#  'longitude': '143.805',
#  'surface_temperature_celcius': 76}
# {'_id': 10843,
#  'confidence': 100,
#  'latitude': '-36.7742',
#  'longitude': '145.1991',
#  'surface_temperature_celcius': 89}
# {'_id': 10852,
#  'confidence': 91,
#  'latitude': '-36.5061',
#  'longitude': '144.5675',
#  'surface_temperature_celcius': 68}
# {'_id': 10856,
#  'confidence': 100,
#  'latitude': '-36.4035',
#  'longitude': '140.9935',
#  'surface_temperature_celcius': 95}
# {'_id': 10865,
#  'confidence': 99,
#  'latitude': '-36.4286',
#  'longitude': '141.1567',
#  'surface_temperature_celcius': 84}
# {'_id': 10868,
#  'confidence': 91,
#  'latitude': '-36.3635',
#  'longitude': '142.2809',
#  'surface_temperature_celcius': 68}
# {'_id': 10869,
#  'confidence': 100,
#  'latitude': '-36.664',
#  'longitude': '142.8802',
#  'surface_temperature_celcius': 87}
# {'_id': 10871,
#  'confidence': 91,
#  'latitude': '-36.6564',
#  'longitude': '142.8615',
#  'surface_temperature_celcius': 69}
# {'_id': 10889,
#  'confidence': 93,
#  'latitude': '-36.6657',
#  'longitude': '143.1675',
#  'surface_temperature_celcius': 72}
# {'_id': 10903,
#  'confidence': 98,
#  'latitude': '-36.8742',
#  'longitude': '142.7177',
#  'surface_temperature_celcius': 84}
# {'_id': 10907,
#  'confidence': 91,
#  'latitude': '-36.7751',
#  'longitude': '145.1696',
#  'surface_temperature_celcius': 68}
# {'_id': 10911,
#  'confidence': 91,
#  'latitude': '-36.3961',
#  'longitude': '140.9781',
#  'surface_temperature_celcius': 69}
# {'_id': 10913,
#  'confidence': 100,
#  'latitude': '-36.7708',
#  'longitude': '145.1908',
#  'surface_temperature_celcius': 98}
# {'_id': 10917,
#  'confidence': 98,
#  'latitude': '-37.758',
#  'longitude': '143.179',
#  'surface_temperature_celcius': 82}
# {'_id': 10918,
#  'confidence': 94,
#  'latitude': '-37.7609',
#  'longitude': '143.1633',
#  'surface_temperature_celcius': 74}
# {'_id': 10919,
#  'confidence': 89,
#  'latitude': '-36.5116',
#  'longitude': '144.562',
#  'surface_temperature_celcius': 66}
# {'_id': 10921,
#  'confidence': 92,
#  'latitude': '-36.803',
#  'longitude': '142.9261',
#  'surface_temperature_celcius': 70}
# {'_id': 10926,
#  'confidence': 89,
#  'latitude': '-36.4143',
#  'longitude': '143.272',
#  'surface_temperature_celcius': 65}
# {'_id': 10930,
#  'confidence': 99,
#  'latitude': '-36.7153',
#  'longitude': '143.8226',
#  'surface_temperature_celcius': 86}
# {'_id': 10933,
#  'confidence': 100,
#  'latitude': '-36.8791',
#  'longitude': '142.7261',
#  'surface_temperature_celcius': 93}
# {'_id': 10936,
#  'confidence': 100,
#  'latitude': '-36.7309',
#  'longitude': '142.3633',
#  'surface_temperature_celcius': 88}
# {'_id': 10937,
#  'confidence': 92,
#  'latitude': '-36.882',
#  'longitude': '142.7108',
#  'surface_temperature_celcius': 70}
# {'_id': 10944,
#  'confidence': 93,
#  'latitude': '-37.5135',
#  'longitude': '142.7238',
#  'surface_temperature_celcius': 72}
# {'_id': 10945,
#  'confidence': 94,
#  'latitude': '-36.2121',
#  'longitude': '144.6885',
#  'surface_temperature_celcius': 74}
# {'_id': 10950,
#  'confidence': 97,
#  'latitude': '-36.2206',
#  'longitude': '144.6856',
#  'surface_temperature_celcius': 80}
# {'_id': 10955,
#  'confidence': 88,
#  'latitude': '-38.0132',
#  'longitude': '146.5269',
#  'surface_temperature_celcius': 73}
# {'_id': 10957,
#  'confidence': 87,
#  'latitude': '-38.0148',
#  'longitude': '146.5413',
#  'surface_temperature_celcius': 71}
# {'_id': 10958,
#  'confidence': 100,
#  'latitude': '-37.8412',
#  'longitude': '147.2536',
#  'surface_temperature_celcius': 87}
# {'_id': 10959,
#  'confidence': 96,
#  'latitude': '-37.8429',
#  'longitude': '147.2691',
#  'surface_temperature_celcius': 78}
# {'_id': 10962,
#  'confidence': 100,
#  'latitude': '-36.5454',
#  'longitude': '144.7402',
#  'surface_temperature_celcius': 96}
# {'_id': 10966,
#  'confidence': 92,
#  'latitude': '-36.7593',
#  'longitude': '142.895',
#  'surface_temperature_celcius': 69}
# {'_id': 10976,
#  'confidence': 90,
#  'latitude': '-36.3435',
#  'longitude': '141.5513',
#  'surface_temperature_celcius': 67}
# {'_id': 10982,
#  'confidence': 93,
#  'latitude': '-36.6942',
#  'longitude': '143.8021',
#  'surface_temperature_celcius': 72}
# {'_id': 10985,
#  'confidence': 100,
#  'latitude': '-36.3459',
#  'longitude': '141.5586',
#  'surface_temperature_celcius': 91}
# {'_id': 10990,
#  'confidence': 93,
#  'latitude': '-36.4046',
#  'longitude': '141.1534',
#  'surface_temperature_celcius': 73}
# {'_id': 10995,
#  'confidence': 96,
#  'latitude': '-36.0594',
#  'longitude': '141.5907',
#  'surface_temperature_celcius': 79}
# {'_id': 10996,
#  'confidence': 100,
#  'latitude': '-36.0576',
#  'longitude': '141.6122',
#  'surface_temperature_celcius': 94}
# {'_id': 11006,
#  'confidence': 93,
#  'latitude': '-36.388',
#  'longitude': '141.8309',
#  'surface_temperature_celcius': 73}
# {'_id': 11008,
#  'confidence': 90,
#  'latitude': '-36.094',
#  'longitude': '145.7646',
#  'surface_temperature_celcius': 67}
# {'_id': 11017,
#  'confidence': 99,
#  'latitude': '-36.5438',
#  'longitude': '144.7548',
#  'surface_temperature_celcius': 84}
# {'_id': 11020,
#  'confidence': 95,
#  'latitude': '-36.6537',
#  'longitude': '143.8781',
#  'surface_temperature_celcius': 76}
# {'_id': 11026,
#  'confidence': 100,
#  'latitude': '-38.1917',
#  'longitude': '147.0745',
#  'surface_temperature_celcius': 94}
# {'_id': 11028,
#  'confidence': 95,
#  'latitude': '-38.1987',
#  'longitude': '147.0666',
#  'surface_temperature_celcius': 76}
# {'_id': 11045,
#  'confidence': 70,
#  'latitude': '-36.9303',
#  'longitude': '143.1034',
#  'surface_temperature_celcius': 72}
# {'_id': 11047,
#  'confidence': 83,
#  'latitude': '-36.3195',
#  'longitude': '146.0601',
#  'surface_temperature_celcius': 77}
# {'_id': 11048,
#  'confidence': 100,
#  'latitude': '-36.5839',
#  'longitude': '143.0588',
#  'surface_temperature_celcius': 99}
# {'_id': 11049,
#  'confidence': 100,
#  'latitude': '-36.5854',
#  'longitude': '143.0462',
#  'surface_temperature_celcius': 94}
# {'_id': 11051,
#  'confidence': 95,
#  'latitude': '-36.3014',
#  'longitude': '143.203',
#  'surface_temperature_celcius': 76}
# {'_id': 11056,
#  'confidence': 87,
#  'latitude': '-36.3332',
#  'longitude': '145.8594',
#  'surface_temperature_celcius': 90}
# {'_id': 11067,
#  'confidence': 86,
#  'latitude': '-37.6775',
#  'longitude': '148.5131',
#  'surface_temperature_celcius': 78}
# {'_id': 11078,
#  'confidence': 93,
#  'latitude': '-36.9111',
#  'longitude': '142.692',
#  'surface_temperature_celcius': 72}
# {'_id': 11084,
#  'confidence': 99,
#  'latitude': '-37.5115',
#  'longitude': '143.14',
#  'surface_temperature_celcius': 86}
# {'_id': 11095,
#  'confidence': 93,
#  'latitude': '-37.769',
#  'longitude': '147.94',
#  'surface_temperature_celcius': 72}
# {'_id': 11098,
#  'confidence': 90,
#  'latitude': '-36.1303',
#  'longitude': '146.3606',
#  'surface_temperature_celcius': 67}
# {'_id': 11105,
#  'confidence': 98,
#  'latitude': '-36.1345',
#  'longitude': '146.351',
#  'surface_temperature_celcius': 84}
# {'_id': 11112,
#  'confidence': 99,
#  'latitude': '-36.1586',
#  'longitude': '145.6666',
#  'surface_temperature_celcius': 85}
# {'_id': 11116,
#  'confidence': 96,
#  'latitude': '-36.5847',
#  'longitude': '145.1968',
#  'surface_temperature_celcius': 78}
# {'_id': 11135,
#  'confidence': 89,
#  'latitude': '-37.876',
#  'longitude': '143.7804',
#  'surface_temperature_celcius': 65}
# {'_id': 11136,
#  'confidence': 88,
#  'latitude': '-36.1546',
#  'longitude': '141.8146',
#  'surface_temperature_celcius': 74}
# {'_id': 11139,
#  'confidence': 87,
#  'latitude': '-37.9091',
#  'longitude': '143.5105',
#  'surface_temperature_celcius': 70}
# {'_id': 11143,
#  'confidence': 80,
#  'latitude': '-36.1559',
#  'longitude': '141.8102',
#  'surface_temperature_celcius': 66}
# {'_id': 11147,
#  'confidence': 100,
#  'latitude': '-37.9071',
#  'longitude': '143.538',
#  'surface_temperature_celcius': 88}
# {'_id': 11153,
#  'confidence': 100,
#  'latitude': '-37.3902',
#  'longitude': '148.2955',
#  'surface_temperature_celcius': 98}
# {'_id': 11155,
#  'confidence': 100,
#  'latitude': '-37.5027',
#  'longitude': '146.347',
#  'surface_temperature_celcius': 95}
# {'_id': 11156,
#  'confidence': 100,
#  'latitude': '-37.5043',
#  'longitude': '146.3299',
#  'surface_temperature_celcius': 93}
# {'_id': 11167,
#  'confidence': 93,
#  'latitude': '-36.1964',
#  'longitude': '144.5217',
#  'surface_temperature_celcius': 72}
# {'_id': 11180,
#  'confidence': 91,
#  'latitude': '-37.6397',
#  'longitude': '142.5968',
#  'surface_temperature_celcius': 68}
# {'_id': 11185,
#  'confidence': 90,
#  'latitude': '-37.6267',
#  'longitude': '142.9993',
#  'surface_temperature_celcius': 66}
# {'_id': 11194,
#  'confidence': 93,
#  'latitude': '-36.5871',
#  'longitude': '144.4958',
#  'surface_temperature_celcius': 72}
# {'_id': 11197,
#  'confidence': 89,
#  'latitude': '-36.2618',
#  'longitude': '141.8783',
#  'surface_temperature_celcius': 65}
# {'_id': 11199,
#  'confidence': 90,
#  'latitude': '-36.6828',
#  'longitude': '144.784',
#  'surface_temperature_celcius': 66}
# {'_id': 11202,
#  'confidence': 89,
#  'latitude': '-37.4843',
#  'longitude': '143.0592',
#  'surface_temperature_celcius': 66}
# {'_id': 11227,
#  'confidence': 94,
#  'latitude': '-37.7274',
#  'longitude': '142.9536',
#  'surface_temperature_celcius': 73}
# {'_id': 11228,
#  'confidence': 91,
#  'latitude': '-37.6964',
#  'longitude': '142.8583',
#  'surface_temperature_celcius': 69}
# {'_id': 11232,
#  'confidence': 98,
#  'latitude': '-38.0509',
#  'longitude': '143.9423',
#  'surface_temperature_celcius': 82}
# {'_id': 11234,
#  'confidence': 92,
#  'latitude': '-37.9284',
#  'longitude': '143.108',
#  'surface_temperature_celcius': 70}
# {'_id': 11238,
#  'confidence': 100,
#  'latitude': '-37.5701',
#  'longitude': '142.6497',
#  'surface_temperature_celcius': 94}
# {'_id': 11248,
#  'confidence': 90,
#  'latitude': '-36.7101',
#  'longitude': '142.3865',
#  'surface_temperature_celcius': 67}
# {'_id': 11253,
#  'confidence': 93,
#  'latitude': '-38.1693',
#  'longitude': '143.0466',
#  'surface_temperature_celcius': 73}
# {'_id': 11255,
#  'confidence': 95,
#  'latitude': '-36.7128',
#  'longitude': '142.3717',
#  'surface_temperature_celcius': 77}
# {'_id': 11256,
#  'confidence': 97,
#  'latitude': '-37.4885',
#  'longitude': '142.0658',
#  'surface_temperature_celcius': 81}
# {'_id': 11268,
#  'confidence': 77,
#  'latitude': '-36.7101',
#  'longitude': '142.981',
#  'surface_temperature_celcius': 68}
# {'_id': 11269,
#  'confidence': 89,
#  'latitude': '-37.0959',
#  'longitude': '143.8206',
#  'surface_temperature_celcius': 65}
# {'_id': 11273,
#  'confidence': 100,
#  'latitude': '-37.9594',
#  'longitude': '143.5638',
#  'surface_temperature_celcius': 87}
# {'_id': 11279,
#  'confidence': 98,
#  'latitude': '-36.5921',
#  'longitude': '144.4905',
#  'surface_temperature_celcius': 82}
# {'_id': 11291,
#  'confidence': 96,
#  'latitude': '-36.6787',
#  'longitude': '144.8042',
#  'surface_temperature_celcius': 79}
# {'_id': 11299,
#  'confidence': 84,
#  'latitude': '-38.0423',
#  'longitude': '146.4048',
#  'surface_temperature_celcius': 66}
# {'_id': 11308,
#  'confidence': 94,
#  'latitude': '-38.1224',
#  'longitude': '143.7553',
#  'surface_temperature_celcius': 73}
# {'_id': 11313,
#  'confidence': 94,
#  'latitude': '-38.0792',
#  'longitude': '143.7361',
#  'surface_temperature_celcius': 93}
# {'_id': 11329,
#  'confidence': 93,
#  'latitude': '-37.9157',
#  'longitude': '143.3544',
#  'surface_temperature_celcius': 72}
# {'_id': 11350,
#  'confidence': 96,
#  'latitude': '-37.7935',
#  'longitude': '143.1606',
#  'surface_temperature_celcius': 78}
# {'_id': 11353,
#  'confidence': 90,
#  'latitude': '-37.7756',
#  'longitude': '143.1388',
#  'surface_temperature_celcius': 67}
# {'_id': 11362,
#  'confidence': 91,
#  'latitude': '-37.7171',
#  'longitude': '142.9505',
#  'surface_temperature_celcius': 68}
# {'_id': 11363,
#  'confidence': 94,
#  'latitude': '-37.7236',
#  'longitude': '142.947',
#  'surface_temperature_celcius': 73}
# {'_id': 11365,
#  'confidence': 100,
#  'latitude': '-37.7002',
#  'longitude': '142.9562',
#  'surface_temperature_celcius': 89}
# {'_id': 11375,
#  'confidence': 92,
#  'latitude': '-37.6498',
#  'longitude': '142.5997',
#  'surface_temperature_celcius': 70}
# {'_id': 11379,
#  'confidence': 100,
#  'latitude': '-37.5728',
#  'longitude': '142.6348',
#  'surface_temperature_celcius': 98}
# {'_id': 11382,
#  'confidence': 100,
#  'latitude': '-37.4352',
#  'longitude': '143.1444',
#  'surface_temperature_celcius': 96}
# {'_id': 11418,
#  'confidence': 92,
#  'latitude': '-36.5828',
#  'longitude': '144.5775',
#  'surface_temperature_celcius': 70}
# {'_id': 11419,
#  'confidence': 96,
#  'latitude': '-36.5987',
#  'longitude': '144.4995',
#  'surface_temperature_celcius': 79}
# {'_id': 11429,
#  'confidence': 98,
#  'latitude': '-36.5262',
#  'longitude': '144.5737',
#  'surface_temperature_celcius': 84}
# {'_id': 11439,
#  'confidence': 95,
#  'latitude': '-36.6995',
#  'longitude': '142.978',
#  'surface_temperature_celcius': 76}
# {'_id': 11444,
#  'confidence': 93,
#  'latitude': '-36.8879',
#  'longitude': '141.6647',
#  'surface_temperature_celcius': 72}
# {'_id': 11456,
#  'confidence': 100,
#  'latitude': '-35.8768',
#  'longitude': '145.4627',
#  'surface_temperature_celcius': 86}
# {'_id': 11457,
#  'confidence': 93,
#  'latitude': '-36.4899',
#  'longitude': '142.2805',
#  'surface_temperature_celcius': 73}
# {'_id': 11459,
#  'confidence': 93,
#  'latitude': '-36.663',
#  'longitude': '141.3038',
#  'surface_temperature_celcius': 72}
# {'_id': 11471,
#  'confidence': 94,
#  'latitude': '-36.092',
#  'longitude': '141.7306',
#  'surface_temperature_celcius': 75}
# {'_id': 11473,
#  'confidence': 89,
#  'latitude': '-34.9023',
#  'longitude': '142.0557',
#  'surface_temperature_celcius': 65}
# {'_id': 11479,
#  'confidence': 91,
#  'latitude': '-36.2637',
#  'longitude': '145.3649',
#  'surface_temperature_celcius': 69}
# {'_id': 11480,
#  'confidence': 89,
#  'latitude': '-37.2609',
#  'longitude': '141.7999',
#  'surface_temperature_celcius': 66}
# {'_id': 11483,
#  'confidence': 93,
#  'latitude': '-36.91',
#  'longitude': '141.0704',
#  'surface_temperature_celcius': 73}
# {'_id': 11489,
#  'confidence': 92,
#  'latitude': '-36.2652',
#  'longitude': '145.3769',
#  'surface_temperature_celcius': 70}
# {'_id': 11491,
#  'confidence': 95,
#  'latitude': '-36.738',
#  'longitude': '142.1177',
#  'surface_temperature_celcius': 77}
# {'_id': 11515,
#  'confidence': 95,
#  'latitude': '-36.5199',
#  'longitude': '144.7311',
#  'surface_temperature_celcius': 77}
# {'_id': 11519,
#  'confidence': 91,
#  'latitude': '-37.0782',
#  'longitude': '145.3625',
#  'surface_temperature_celcius': 68}
# {'_id': 11525,
#  'confidence': 94,
#  'latitude': '-36.3966',
#  'longitude': '141.406',
#  'surface_temperature_celcius': 74}
# {'_id': 11528,
#  'confidence': 90,
#  'latitude': '-37.1349',
#  'longitude': '141.9491',
#  'surface_temperature_celcius': 67}
# {'_id': 11544,
#  'confidence': 91,
#  'latitude': '-36.7651',
#  'longitude': '143.5801',
#  'surface_temperature_celcius': 68}
# {'_id': 11555,
#  'confidence': 98,
#  'latitude': '-36.9329',
#  'longitude': '143.7796',
#  'surface_temperature_celcius': 82}
# {'_id': 11558,
#  'confidence': 99,
#  'latitude': '-35.8276',
#  'longitude': '143.7549',
#  'surface_temperature_celcius': 85}
# {'_id': 11575,
#  'confidence': 78,
#  'latitude': '-35.9326',
#  'longitude': '141.958',
#  'surface_temperature_celcius': 66}
# {'_id': 11583,
#  'confidence': 91,
#  'latitude': '-36.6892',
#  'longitude': '145.2775',
#  'surface_temperature_celcius': 69}
# {'_id': 11584,
#  'confidence': 89,
#  'latitude': '-36.73',
#  'longitude': '143.935',
#  'surface_temperature_celcius': 65}
# {'_id': 11586,
#  'confidence': 100,
#  'latitude': '-36.8283',
#  'longitude': '143.4605',
#  'surface_temperature_celcius': 93}
# {'_id': 11591,
#  'confidence': 97,
#  'latitude': '-36.6527',
#  'longitude': '142.7392',
#  'surface_temperature_celcius': 81}
# {'_id': 11592,
#  'confidence': 96,
#  'latitude': '-36.1898',
#  'longitude': '145.0922',
#  'surface_temperature_celcius': 78}
# {'_id': 11598,
#  'confidence': 96,
#  'latitude': '-36.8298',
#  'longitude': '143.4483',
#  'surface_temperature_celcius': 79}
# {'_id': 11601,
#  'confidence': 100,
#  'latitude': '-36.6615',
#  'longitude': '144.6014',
#  'surface_temperature_celcius': 90}
# {'_id': 11602,
#  'confidence': 93,
#  'latitude': '-36.8238',
#  'longitude': '143.5724',
#  'surface_temperature_celcius': 73}
# {'_id': 11621,
#  'confidence': 100,
#  'latitude': '-36.1988',
#  'longitude': '145.0941',
#  'surface_temperature_celcius': 100}
# {'_id': 11623,
#  'confidence': 75,
#  'latitude': '-36.7499',
#  'longitude': '141.3006',
#  'surface_temperature_celcius': 99}
# {'_id': 11630,
#  'confidence': 84,
#  'latitude': '-36.7432',
#  'longitude': '141.3296',
#  'surface_temperature_celcius': 79}
# {'_id': 11632,
#  'confidence': 84,
#  'latitude': '-36.7531',
#  'longitude': '141.3253',
#  'surface_temperature_celcius': 78}
# {'_id': 11636,
#  'confidence': 99,
#  'latitude': '-36.7943',
#  'longitude': '143.9571',
#  'surface_temperature_celcius': 84}
# {'_id': 11638,
#  'confidence': 100,
#  'latitude': '-36.7957',
#  'longitude': '143.9652',
#  'surface_temperature_celcius': 87}
# {'_id': 11641,
#  'confidence': 96,
#  'latitude': '-36.9498',
#  'longitude': '142.2012',
#  'surface_temperature_celcius': 78}
# {'_id': 11642,
#  'confidence': 93,
#  'latitude': '-36.1941',
#  'longitude': '143.1604',
#  'surface_temperature_celcius': 72}
# {'_id': 11643,
#  'confidence': 100,
#  'latitude': '-36.4142',
#  'longitude': '143.1077',
#  'surface_temperature_celcius': 97}
# {'_id': 11645,
#  'confidence': 92,
#  'latitude': '-36.1924',
#  'longitude': '143.1716',
#  'surface_temperature_celcius': 70}
# {'_id': 11649,
#  'confidence': 89,
#  'latitude': '-36.0295',
#  'longitude': '143.6409',
#  'surface_temperature_celcius': 65}
# {'_id': 11656,
#  'confidence': 100,
#  'latitude': '-37.0761',
#  'longitude': '141.0574',
#  'surface_temperature_celcius': 89}
# {'_id': 11658,
#  'confidence': 93,
#  'latitude': '-35.0616',
#  'longitude': '141.4417',
#  'surface_temperature_celcius': 73}
# {'_id': 11659,
#  'confidence': 100,
#  'latitude': '-36.3999',
#  'longitude': '144.737',
#  'surface_temperature_celcius': 88}
# {'_id': 11665,
#  'confidence': 91,
#  'latitude': '-36.1748',
#  'longitude': '145.7582',
#  'surface_temperature_celcius': 69}
# {'_id': 11666,
#  'confidence': 99,
#  'latitude': '-36.0691',
#  'longitude': '145.7797',
#  'surface_temperature_celcius': 85}
# {'_id': 11669,
#  'confidence': 90,
#  'latitude': '-35.1949',
#  'longitude': '141.0622',
#  'surface_temperature_celcius': 66}
# {'_id': 11672,
#  'confidence': 100,
#  'latitude': '-36.91',
#  'longitude': '141.2705',
#  'surface_temperature_celcius': 96}
# {'_id': 11675,
#  'confidence': 89,
#  'latitude': '-35.8071',
#  'longitude': '142.7318',
#  'surface_temperature_celcius': 66}
# {'_id': 11677,
#  'confidence': 97,
#  'latitude': '-36.7787',
#  'longitude': '141.4449',
#  'surface_temperature_celcius': 80}
# {'_id': 11694,
#  'confidence': 98,
#  'latitude': '-36.2948',
#  'longitude': '141.3486',
#  'surface_temperature_celcius': 82}
# {'_id': 11695,
#  'confidence': 89,
#  'latitude': '-38.1561',
#  'longitude': '143.7846',
#  'surface_temperature_celcius': 65}
# {'_id': 11697,
#  'confidence': 90,
#  'latitude': '-37.8185',
#  'longitude': '142.5609',
#  'surface_temperature_celcius': 66}
# {'_id': 11716,
#  'confidence': 100,
#  'latitude': '-36.1771',
#  'longitude': '145.7451',
#  'surface_temperature_celcius': 93}
# {'_id': 11719,
#  'confidence': 100,
#  'latitude': '-38.027',
#  'longitude': '142.3844',
#  'surface_temperature_celcius': 95}
# {'_id': 11721,
#  'confidence': 89,
#  'latitude': '-35.7642',
#  'longitude': '143.3321',
#  'surface_temperature_celcius': 65}
# {'_id': 11726,
#  'confidence': 90,
#  'latitude': '-36.429',
#  'longitude': '141.5759',
#  'surface_temperature_celcius': 67}
# {'_id': 11727,
#  'confidence': 92,
#  'latitude': '-36.1346',
#  'longitude': '145.2196',
#  'surface_temperature_celcius': 71}
# {'_id': 11731,
#  'confidence': 100,
#  'latitude': '-37.0899',
#  'longitude': '141.0238',
#  'surface_temperature_celcius': 90}
# {'_id': 11744,
#  'confidence': 95,
#  'latitude': '-36.3823',
#  'longitude': '141.3146',
#  'surface_temperature_celcius': 77}
# {'_id': 11745,
#  'confidence': 90,
#  'latitude': '-36.1462',
#  'longitude': '145.2096',
#  'surface_temperature_celcius': 66}
# {'_id': 11747,
#  'confidence': 93,
#  'latitude': '-36.5243',
#  'longitude': '142.0839',
#  'surface_temperature_celcius': 72}
# {'_id': 11755,
#  'confidence': 98,
#  'latitude': '-37.618',
#  'longitude': '143.0013',
#  'surface_temperature_celcius': 82}
# {'_id': 11756,
#  'confidence': 90,
#  'latitude': '-36.8867',
#  'longitude': '142.1873',
#  'surface_temperature_celcius': 66}
# {'_id': 11758,
#  'confidence': 92,
#  'latitude': '-36.9364',
#  'longitude': '143.4996',
#  'surface_temperature_celcius': 70}
# {'_id': 11760,
#  'confidence': 100,
#  'latitude': '-37.3847',
#  'longitude': '142.8935',
#  'surface_temperature_celcius': 88}
# {'_id': 11767,
#  'confidence': 100,
#  'latitude': '-35.6374',
#  'longitude': '142.3787',
#  'surface_temperature_celcius': 95}
# {'_id': 11768,
#  'confidence': 90,
#  'latitude': '-36.8835',
#  'longitude': '142.2098',
#  'surface_temperature_celcius': 67}
# {'_id': 11769,
#  'confidence': 100,
#  'latitude': '-36.4125',
#  'longitude': '143.1189',
#  'surface_temperature_celcius': 92}
# {'_id': 11773,
#  'confidence': 97,
#  'latitude': '-37.0669',
#  'longitude': '141.0556',
#  'surface_temperature_celcius': 80}
# {'_id': 11776,
#  'confidence': 92,
#  'latitude': '-36.0714',
#  'longitude': '145.7665',
#  'surface_temperature_celcius': 71}
# {'_id': 11788,
#  'confidence': 94,
#  'latitude': '-36.2933',
#  'longitude': '141.36',
#  'surface_temperature_celcius': 75}
# {'_id': 11791,
#  'confidence': 100,
#  'latitude': '-37.4591',
#  'longitude': '144.9492',
#  'surface_temperature_celcius': 89}
# {'_id': 11793,
#  'confidence': 91,
#  'latitude': '-36.3487',
#  'longitude': '145.5315',
#  'surface_temperature_celcius': 68}
# {'_id': 11809,
#  'confidence': 90,
#  'latitude': '-36.5399',
#  'longitude': '144.678',
#  'surface_temperature_celcius': 66}
# {'_id': 11812,
#  'confidence': 97,
#  'latitude': '-36.8158',
#  'longitude': '142.6229',
#  'surface_temperature_celcius': 80}
# {'_id': 11813,
#  'confidence': 100,
#  'latitude': '-36.4518',
#  'longitude': '144.7752',
#  'surface_temperature_celcius': 97}
# {'_id': 11815,
#  'confidence': 90,
#  'latitude': '-36.7903',
#  'longitude': '141.618',
#  'surface_temperature_celcius': 67}
# {'_id': 11827,
#  'confidence': 97,
#  'latitude': '-36.1067',
#  'longitude': '143.7948',
#  'surface_temperature_celcius': 79}
# {'_id': 11828,
#  'confidence': 89,
#  'latitude': '-36.1441',
#  'longitude': '145.2221',
#  'surface_temperature_celcius': 65}
# {'_id': 11837,
#  'confidence': 94,
#  'latitude': '-36.4816',
#  'longitude': '141.6635',
#  'surface_temperature_celcius': 75}
# {'_id': 11839,
#  'confidence': 100,
#  'latitude': '-36.0837',
#  'longitude': '144.2448',
#  'surface_temperature_celcius': 87}
# {'_id': 11844,
#  'confidence': 90,
#  'latitude': '-36.782',
#  'longitude': '141.8851',
#  'surface_temperature_celcius': 67}
# {'_id': 11853,
#  'confidence': 92,
#  'latitude': '-36.5586',
#  'longitude': '144.0423',
#  'surface_temperature_celcius': 71}
# {'_id': 11854,
#  'confidence': 90,
#  'latitude': '-36.5568',
#  'longitude': '144.0538',
#  'surface_temperature_celcius': 68}
# {'_id': 11855,
#  'confidence': 97,
#  'latitude': '-36.4538',
#  'longitude': '144.763',
#  'surface_temperature_celcius': 81}
# {'_id': 11857,
#  'confidence': 91,
#  'latitude': '-36.4612',
#  'longitude': '144.7775',
#  'surface_temperature_celcius': 80}
# {'_id': 11860,
#  'confidence': 100,
#  'latitude': '-36.7089',
#  'longitude': '143.3518',
#  'surface_temperature_celcius': 93}
# {'_id': 11871,
#  'confidence': 97,
#  'latitude': '-36.601',
#  'longitude': '144.6378',
#  'surface_temperature_celcius': 80}
# {'_id': 11880,
#  'confidence': 95,
#  'latitude': '-36.8681',
#  'longitude': '143.5186',
#  'surface_temperature_celcius': 76}
# {'_id': 11890,
#  'confidence': 100,
#  'latitude': '-37.1999',
#  'longitude': '143.8231',
#  'surface_temperature_celcius': 90}
# {'_id': 11902,
#  'confidence': 91,
#  'latitude': '-37.6171',
#  'longitude': '142.9426',
#  'surface_temperature_celcius': 68}
# {'_id': 11909,
#  'confidence': 84,
#  'latitude': '-37.7587',
#  'longitude': '142.8521',
#  'surface_temperature_celcius': 80}
# {'_id': 11913,
#  'confidence': 91,
#  'latitude': '-37.4611',
#  'longitude': '144.9371',
#  'surface_temperature_celcius': 69}
# {'_id': 11923,
#  'confidence': 100,
#  'latitude': '-38.0254',
#  'longitude': '142.3959',
#  'surface_temperature_celcius': 99}
# {'_id': 11928,
#  'confidence': 89,
#  'latitude': '-37.88',
#  'longitude': '143.7233',
#  'surface_temperature_celcius': 65}
# {'_id': 11931,
#  'confidence': 99,
#  'latitude': '-37.8885',
#  'longitude': '143.9157',
#  'surface_temperature_celcius': 85}
# {'_id': 11935,
#  'confidence': 95,
#  'latitude': '-35.0706',
#  'longitude': '141.4435',
#  'surface_temperature_celcius': 75}
# {'_id': 11936,
#  'confidence': 100,
#  'latitude': '-38.0795',
#  'longitude': '143.2449',
#  'surface_temperature_celcius': 91}
# {'_id': 11939,
#  'confidence': 100,
#  'latitude': '-35.1857',
#  'longitude': '141.0604',
#  'surface_temperature_celcius': 92}
# {'_id': 11948,
#  'confidence': 100,
#  'latitude': '-35.6469',
#  'longitude': '142.376',
#  'surface_temperature_celcius': 93}
# {'_id': 11949,
#  'confidence': 91,
#  'latitude': '-35.6453',
#  'longitude': '142.387',
#  'surface_temperature_celcius': 69}
# {'_id': 11954,
#  'confidence': 100,
#  'latitude': '-36.4409',
#  'longitude': '141.6948',
#  'surface_temperature_celcius': 92}
# {'_id': 11957,
#  'confidence': 100,
#  'latitude': '-37.9174',
#  'longitude': '145.8678',
#  'surface_temperature_celcius': 93}
# {'_id': 11958,
#  'confidence': 95,
#  'latitude': '-37.9152',
#  'longitude': '145.8808',
#  'surface_temperature_celcius': 77}
# {'_id': 11961,
#  'confidence': 95,
#  'latitude': '-37.8906',
#  'longitude': '146.2035',
#  'surface_temperature_celcius': 75}
# {'_id': 11970,
#  'confidence': 100,
#  'latitude': '-35.8182',
#  'longitude': '143.8739',
#  'surface_temperature_celcius': 92}
# {'_id': 11973,
#  'confidence': 100,
#  'latitude': '-37.9246',
#  'longitude': '146.2464',
#  'surface_temperature_celcius': 96}
# {'_id': 11974,
#  'confidence': 94,
#  'latitude': '-36.3313',
#  'longitude': '141.0017',
#  'surface_temperature_celcius': 73}
# {'_id': 11976,
#  'confidence': 90,
#  'latitude': '-36.2857',
#  'longitude': '141.3467',
#  'surface_temperature_celcius': 67}
# {'_id': 11978,
#  'confidence': 92,
#  'latitude': '-36.0749',
#  'longitude': '143.4058',
#  'surface_temperature_celcius': 70}
# {'_id': 11981,
#  'confidence': 91,
#  'latitude': '-36.4449',
#  'longitude': '140.9836',
#  'surface_temperature_celcius': 68}
# {'_id': 11986,
#  'confidence': 100,
#  'latitude': '-36.3972',
#  'longitude': '141.6041',
#  'surface_temperature_celcius': 90}
# {'_id': 11987,
#  'confidence': 90,
#  'latitude': '-36.5532',
#  'longitude': '142.5349',
#  'surface_temperature_celcius': 67}
# {'_id': 11988,
#  'confidence': 92,
#  'latitude': '-36.1367',
#  'longitude': '145.2071',
#  'surface_temperature_celcius': 71}
# {'_id': 11994,
#  'confidence': 96,
#  'latitude': '-36.1518',
#  'longitude': '144.0233',
#  'surface_temperature_celcius': 79}
# {'_id': 11995,
#  'confidence': 95,
#  'latitude': '-36.1418',
#  'longitude': '144.0261',
#  'surface_temperature_celcius': 76}
# {'_id': 12009,
#  'confidence': 94,
#  'latitude': '-37.5812',
#  'longitude': '142.7374',
#  'surface_temperature_celcius': 75}
# {'_id': 12011,
#  'confidence': 100,
#  'latitude': '-37.5949',
#  'longitude': '142.6857',
#  'surface_temperature_celcius': 98}
# {'_id': 12015,
#  'confidence': 95,
#  'latitude': '-37.8247',
#  'longitude': '143.6243',
#  'surface_temperature_celcius': 77}
# {'_id': 12021,
#  'confidence': 95,
#  'latitude': '-37.4028',
#  'longitude': '143.6932',
#  'surface_temperature_celcius': 75}
# {'_id': 12023,
#  'confidence': 92,
#  'latitude': '-37.4033',
#  'longitude': '143.6884',
#  'surface_temperature_celcius': 70}
# {'_id': 12039,
#  'confidence': 100,
#  'latitude': '-37.8249',
#  'longitude': '143.6174',
#  'surface_temperature_celcius': 98}
# {'_id': 12049,
#  'confidence': 93,
#  'latitude': '-36.6823',
#  'longitude': '142.5024',
#  'surface_temperature_celcius': 71}
# {'_id': 12057,
#  'confidence': 93,
#  'latitude': '-36.4489',
#  'longitude': '144.7685',
#  'surface_temperature_celcius': 73}
# {'_id': 12091,
#  'confidence': 67,
#  'latitude': '-37.34',
#  'longitude': '149.3668',
#  'surface_temperature_celcius': 74}
# {'_id': 12093,
#  'confidence': 99,
#  'latitude': '-36.7287',
#  'longitude': '142.6017',
#  'surface_temperature_celcius': 85}
# {'_id': 12094,
#  'confidence': 91,
#  'latitude': '-35.2363',
#  'longitude': '143.0004',
#  'surface_temperature_celcius': 69}
# {'_id': 12096,
#  'confidence': 100,
#  'latitude': '-35.2378',
#  'longitude': '142.9864',
#  'surface_temperature_celcius': 94}
# {'_id': 12102,
#  'confidence': 98,
#  'latitude': '-35.2381',
#  'longitude': '142.994',
#  'surface_temperature_celcius': 83}
# {'_id': 12104,
#  'confidence': 66,
#  'latitude': '-37.3493',
#  'longitude': '149.3691',
#  'surface_temperature_celcius': 80}
# {'_id': 12106,
#  'confidence': 90,
#  'latitude': '-36.7165',
#  'longitude': '142.6155',
#  'surface_temperature_celcius': 66}
# {'_id': 12143,
#  'confidence': 100,
#  'latitude': '-37.2168',
#  'longitude': '147.4748',
#  'surface_temperature_celcius': 89}
# {'_id': 12144,
#  'confidence': 96,
#  'latitude': '-37.222',
#  'longitude': '147.4689',
#  'surface_temperature_celcius': 78}
# {'_id': 12146,
#  'confidence': 92,
#  'latitude': '-37.2063',
#  'longitude': '147.4713',
#  'surface_temperature_celcius': 70}
# {'_id': 12147,
#  'confidence': 92,
#  'latitude': '-37.2082',
#  'longitude': '147.4368',
#  'surface_temperature_celcius': 70}
# {'_id': 12148,
#  'confidence': 95,
#  'latitude': '-37.224',
#  'longitude': '147.4347',
#  'surface_temperature_celcius': 76}
# {'_id': 12151,
#  'confidence': 84,
#  'latitude': '-37.5816',
#  'longitude': '148.5862',
#  'surface_temperature_celcius': 65}
# {'_id': 12152,
#  'confidence': 92,
#  'latitude': '-36.6334',
#  'longitude': '142.2244',
#  'surface_temperature_celcius': 69}
# {'_id': 12153,
#  'confidence': 76,
#  'latitude': '-37.7966',
#  'longitude': '142.3196',
#  'surface_temperature_celcius': 66}
# {'_id': 12154,
#  'confidence': 100,
#  'latitude': '-35.805',
#  'longitude': '142.1326',
#  'surface_temperature_celcius': 95}
# {'_id': 12155,
#  'confidence': 100,
#  'latitude': '-37.8429',
#  'longitude': '143.8366',
#  'surface_temperature_celcius': 88}
# {'_id': 12157,
#  'confidence': 77,
#  'latitude': '-37.8062',
#  'longitude': '143.3598',
#  'surface_temperature_celcius': 65}
# {'_id': 12159,
#  'confidence': 100,
#  'latitude': '-36.9918',
#  'longitude': '141.8667',
#  'surface_temperature_celcius': 97}
# {'_id': 12161,
#  'confidence': 90,
#  'latitude': '-36.1104',
#  'longitude': '145.9829',
#  'surface_temperature_celcius': 76}
# {'_id': 12162,
#  'confidence': 100,
#  'latitude': '-37.782',
#  'longitude': '148.3844',
#  'surface_temperature_celcius': 99}
# {'_id': 12168,
#  'confidence': 89,
#  'latitude': '-36.9902',
#  'longitude': '141.879',
#  'surface_temperature_celcius': 65}
# {'_id': 12169,
#  'confidence': 89,
#  'latitude': '-37.745',
#  'longitude': '142.993',
#  'surface_temperature_celcius': 65}
# {'_id': 12173,
#  'confidence': 92,
#  'latitude': '-36.0157',
#  'longitude': '145.9414',
#  'surface_temperature_celcius': 70}
# {'_id': 12177,
#  'confidence': 99,
#  'latitude': '-37.777',
#  'longitude': '148.4128',
#  'surface_temperature_celcius': 85}
# {'_id': 12178,
#  'confidence': 93,
#  'latitude': '-37.5888',
#  'longitude': '148.5949',
#  'surface_temperature_celcius': 72}
# {'_id': 12180,
#  'confidence': 89,
#  'latitude': '-34.3943',
#  'longitude': '141.7567',
#  'surface_temperature_celcius': 65}
# {'_id': 12188,
#  'confidence': 81,
#  'latitude': '-36.0844',
#  'longitude': '141.4934',
#  'surface_temperature_celcius': 71}
# {'_id': 12193,
#  'confidence': 91,
#  'latitude': '-36.031',
#  'longitude': '145.6824',
#  'surface_temperature_celcius': 69}
# {'_id': 12195,
#  'confidence': 86,
#  'latitude': '-37.5814',
#  'longitude': '148.5777',
#  'surface_temperature_celcius': 68}
# {'_id': 12198,
#  'confidence': 90,
#  'latitude': '-37.5788',
#  'longitude': '148.592',
#  'surface_temperature_celcius': 67}
# {'_id': 12200,
#  'confidence': 90,
#  'latitude': '-36.6384',
#  'longitude': '142.4075',
#  'surface_temperature_celcius': 66}
# {'_id': 12205,
#  'confidence': 94,
#  'latitude': '-35.811',
#  'longitude': '142.1403',
#  'surface_temperature_celcius': 96}
# {'_id': 12211,
#  'confidence': 100,
#  'latitude': '-36.9034',
#  'longitude': '141.0013',
#  'surface_temperature_celcius': 95}
# {'_id': 12212,
#  'confidence': 88,
#  'latitude': '-37.7746',
#  'longitude': '148.3673',
#  'surface_temperature_celcius': 65}
# {'_id': 12217,
#  'confidence': 83,
#  'latitude': '-37.803',
#  'longitude': '142.3151',
#  'surface_temperature_celcius': 78}
# {'_id': 12220,
#  'confidence': 96,
#  'latitude': '-37.7542',
#  'longitude': '142.9949',
#  'surface_temperature_celcius': 77}
# {'_id': 12221,
#  'confidence': 91,
#  'latitude': '-37.3803',
#  'longitude': '145.611',
#  'surface_temperature_celcius': 68}
# {'_id': 12222,
#  'confidence': 97,
#  'latitude': '-37.7617',
#  'longitude': '143.081',
#  'surface_temperature_celcius': 81}
# {'_id': 12225,
#  'confidence': 92,
#  'latitude': '-37.8161',
#  'longitude': '142.9286',
#  'surface_temperature_celcius': 71}
# {'_id': 12242,
#  'confidence': 90,
#  'latitude': '-36.0387',
#  'longitude': '145.6787',
#  'surface_temperature_celcius': 67}
# {'_id': 12244,
#  'confidence': 94,
#  'latitude': '-36.6349',
#  'longitude': '142.2125',
#  'surface_temperature_celcius': 86}
# {'_id': 12250,
#  'confidence': 100,
#  'latitude': '-36.9018',
#  'longitude': '141.0146',
#  'surface_temperature_celcius': 100}
# {'_id': 12251,
#  'confidence': 86,
#  'latitude': '-36.6986',
#  'longitude': '142.7259',
#  'surface_temperature_celcius': 72}
# {'_id': 12262,
#  'confidence': 94,
#  'latitude': '-38.0052',
#  'longitude': '142.6179',
#  'surface_temperature_celcius': 89}
# {'_id': 12284,
#  'confidence': 87,
#  'latitude': '-37.6387',
#  'longitude': '142.9032',
#  'surface_temperature_celcius': 88}
# {'_id': 12288,
#  'confidence': 93,
#  'latitude': '-37.6439',
#  'longitude': '142.913',
#  'surface_temperature_celcius': 83}
# {'_id': 12293,
#  'confidence': 93,
#  'latitude': '-37.3165',
#  'longitude': '147.4932',
#  'surface_temperature_celcius': 72}
# {'_id': 12297,
#  'confidence': 95,
#  'latitude': '-37.3158',
#  'longitude': '147.4986',
#  'surface_temperature_celcius': 76}
# {'_id': 12299,
#  'confidence': 89,
#  'latitude': '-37.4471',
#  'longitude': '147.6331',
#  'surface_temperature_celcius': 65}
# {'_id': 12302,
#  'confidence': 90,
#  'latitude': '-37.7835',
#  'longitude': '148.4138',
#  'surface_temperature_celcius': 66}
# {'_id': 12305,
#  'confidence': 89,
#  'latitude': '-37.4449',
#  'longitude': '147.6594',
#  'surface_temperature_celcius': 65}
# {'_id': 12307,
#  'confidence': 95,
#  'latitude': '-37.4323',
#  'longitude': '147.6583',
#  'surface_temperature_celcius': 76}
# {'_id': 12308,
#  'confidence': 100,
#  'latitude': '-37.4343',
#  'longitude': '147.6327',
#  'surface_temperature_celcius': 92}
# {'_id': 12326,
#  'confidence': 90,
#  'latitude': '-35.4033',
#  'longitude': '143.267',
#  'surface_temperature_celcius': 67}
# {'_id': 12327,
#  'confidence': 64,
#  'latitude': '-36.6281',
#  'longitude': '142.4349',
#  'surface_temperature_celcius': 68}
# {'_id': 12328,
#  'confidence': 85,
#  'latitude': '-36.111',
#  'longitude': '145.124',
#  'surface_temperature_celcius': 66}
# {'_id': 12329,
#  'confidence': 90,
#  'latitude': '-36.1615',
#  'longitude': '141.8728',
#  'surface_temperature_celcius': 66}
# {'_id': 12348,
#  'confidence': 90,
#  'latitude': '-36.1122',
#  'longitude': '142.1491',
#  'surface_temperature_celcius': 76}
# {'_id': 12351,
#  'confidence': 100,
#  'latitude': '-37.3735',
#  'longitude': '145.8384',
#  'surface_temperature_celcius': 95}
# {'_id': 12354,
#  'confidence': 89,
#  'latitude': '-35.4255',
#  'longitude': '143.6306',
#  'surface_temperature_celcius': 65}
# {'_id': 12357,
#  'confidence': 96,
#  'latitude': '-36.1955',
#  'longitude': '145.914',
#  'surface_temperature_celcius': 78}
# {'_id': 12358,
#  'confidence': 85,
#  'latitude': '-35.4533',
#  'longitude': '143.2029',
#  'surface_temperature_celcius': 66}
# {'_id': 12360,
#  'confidence': 92,
#  'latitude': '-36.5989',
#  'longitude': '141.9771',
#  'surface_temperature_celcius': 81}
# {'_id': 12369,
#  'confidence': 66,
#  'latitude': '-36.6299',
#  'longitude': '142.4234',
#  'surface_temperature_celcius': 71}
# {'_id': 12374,
#  'confidence': 97,
#  'latitude': '-36.1925',
#  'longitude': '145.93',
#  'surface_temperature_celcius': 79}
# {'_id': 12376,
#  'confidence': 98,
#  'latitude': '-36.095',
#  'longitude': '141.7699',
#  'surface_temperature_celcius': 82}
# {'_id': 12386,
#  'confidence': 96,
#  'latitude': '-36.6006',
#  'longitude': '141.9657',
#  'surface_temperature_celcius': 78}
# {'_id': 12388,
#  'confidence': 93,
#  'latitude': '-37.0769',
#  'longitude': '141.042',
#  'surface_temperature_celcius': 72}
# {'_id': 12391,
#  'confidence': 79,
#  'latitude': '-36.883',
#  'longitude': '142.1637',
#  'surface_temperature_celcius': 67}
# {'_id': 12392,
#  'confidence': 87,
#  'latitude': '-36.0973',
#  'longitude': '143.4279',
#  'surface_temperature_celcius': 92}
# {'_id': 12402,
#  'confidence': 100,
#  'latitude': '-36.1819',
#  'longitude': '145.9269',
#  'surface_temperature_celcius': 98}
# {'_id': 12412,
#  'confidence': 87,
#  'latitude': '-37.3735',
#  'longitude': '145.886',
#  'surface_temperature_celcius': 96}
# {'_id': 12414,
#  'confidence': 93,
#  'latitude': '-37.7465',
#  'longitude': '143.3806',
#  'surface_temperature_celcius': 72}
# {'_id': 12419,
#  'confidence': 95,
#  'latitude': '-37.8072',
#  'longitude': '145.9738',
#  'surface_temperature_celcius': 77}
# {'_id': 12420,
#  'confidence': 96,
#  'latitude': '-37.3704',
#  'longitude': '145.8942',
#  'surface_temperature_celcius': 78}
# {'_id': 12421,
#  'confidence': 100,
#  'latitude': '-37.297',
#  'longitude': '143.5753',
#  'surface_temperature_celcius': 93}
# {'_id': 12429,
#  'confidence': 100,
#  'latitude': '-37.2988',
#  'longitude': '143.5487',
#  'surface_temperature_celcius': 90}
# {'_id': 12434,
#  'confidence': 100,
#  'latitude': '-37.3025',
#  'longitude': '143.5714',
#  'surface_temperature_celcius': 98}
# {'_id': 12435,
#  'confidence': 100,
#  'latitude': '-37.383',
#  'longitude': '145.9089',
#  'surface_temperature_celcius': 89}
# {'_id': 12440,
#  'confidence': 89,
#  'latitude': '-37.7446',
#  'longitude': '143.4085',
#  'surface_temperature_celcius': 66}
# {'_id': 12445,
#  'confidence': 98,
#  'latitude': '-37.7509',
#  'longitude': '143.4023',
#  'surface_temperature_celcius': 82}
# {'_id': 12448,
#  'confidence': 87,
#  'latitude': '-37.7974',
#  'longitude': '145.9535',
#  'surface_temperature_celcius': 97}
# {'_id': 12453,
#  'confidence': 90,
#  'latitude': '-35.7657',
#  'longitude': '142.0906',
#  'surface_temperature_celcius': 66}
# {'_id': 12461,
#  'confidence': 99,
#  'latitude': '-37.7236',
#  'longitude': '143.3995',
#  'surface_temperature_celcius': 86}
# {'_id': 12463,
#  'confidence': 93,
#  'latitude': '-37.3046',
#  'longitude': '143.5448',
#  'surface_temperature_celcius': 72}
# {'_id': 12466,
#  'confidence': 95,
#  'latitude': '-36.4312',
#  'longitude': '141.2064',
#  'surface_temperature_celcius': 76}
# {'_id': 12469,
#  'confidence': 89,
#  'latitude': '-36.1556',
#  'longitude': '141.5904',
#  'surface_temperature_celcius': 65}
# {'_id': 12472,
#  'confidence': 89,
#  'latitude': '-35.7647',
#  'longitude': '142.0858',
#  'surface_temperature_celcius': 65}
# {'_id': 12516,
#  'confidence': 92,
#  'latitude': '-36.4557',
#  'longitude': '142.2434',
#  'surface_temperature_celcius': 71}
# {'_id': 12517,
#  'confidence': 95,
#  'latitude': '-36.8009',
#  'longitude': '142.7259',
#  'surface_temperature_celcius': 76}
# {'_id': 12519,
#  'confidence': 93,
#  'latitude': '-36.8099',
#  'longitude': '142.728',
#  'surface_temperature_celcius': 73}
# {'_id': 12524,
#  'confidence': 94,
#  'latitude': '-36.7806',
#  'longitude': '141.5597',
#  'surface_temperature_celcius': 74}
# {'_id': 12527,
#  'confidence': 98,
#  'latitude': '-34.3526',
#  'longitude': '141.6458',
#  'surface_temperature_celcius': 82}
# {'_id': 12529,
#  'confidence': 97,
#  'latitude': '-37.0924',
#  'longitude': '141.897',
#  'surface_temperature_celcius': 80}
# {'_id': 12537,
#  'confidence': 97,
#  'latitude': '-37.9452',
#  'longitude': '143.5834',
#  'surface_temperature_celcius': 80}
# {'_id': 12543,
#  'confidence': 99,
#  'latitude': '-34.351',
#  'longitude': '141.6567',
#  'surface_temperature_celcius': 86}
# {'_id': 12549,
#  'confidence': 100,
#  'latitude': '-37.5012',
#  'longitude': '142.5853',
#  'surface_temperature_celcius': 90}
# {'_id': 12553,
#  'confidence': 97,
#  'latitude': '-37.9247',
#  'longitude': '142.8999',
#  'surface_temperature_celcius': 81}
# {'_id': 12561,
#  'confidence': 97,
#  'latitude': '-35.0805',
#  'longitude': '142.4642',
#  'surface_temperature_celcius': 81}
# {'_id': 12574,
#  'confidence': 71,
#  'latitude': '-37.522',
#  'longitude': '143.3874',
#  'surface_temperature_celcius': 73}
# {'_id': 12575,
#  'confidence': 91,
#  'latitude': '-38.0674',
#  'longitude': '142.965',
#  'surface_temperature_celcius': 68}
# {'_id': 12576,
#  'confidence': 92,
#  'latitude': '-38.0715',
#  'longitude': '142.9591',
#  'surface_temperature_celcius': 70}
# {'_id': 12577,
#  'confidence': 100,
#  'latitude': '-38.0693',
#  'longitude': '142.9722',
#  'surface_temperature_celcius': 89}
# {'_id': 12587,
#  'confidence': 82,
#  'latitude': '-37.8973',
#  'longitude': '143.4754',
#  'surface_temperature_celcius': 65}
# {'_id': 12589,
#  'confidence': 95,
#  'latitude': '-37.7805',
#  'longitude': '143.5003',
#  'surface_temperature_celcius': 75}
# {'_id': 12592,
#  'confidence': 95,
#  'latitude': '-37.8774',
#  'longitude': '145.8213',
#  'surface_temperature_celcius': 77}
# {'_id': 12594,
#  'confidence': 100,
#  'latitude': '-37.8881',
#  'longitude': '145.8229',
#  'surface_temperature_celcius': 99}
# {'_id': 12601,
#  'confidence': 96,
#  'latitude': '-37.6622',
#  'longitude': '142.1001',
#  'surface_temperature_celcius': 79}
# {'_id': 12604,
#  'confidence': 90,
#  'latitude': '-37.4523',
#  'longitude': '147.0175',
#  'surface_temperature_celcius': 66}
# {'_id': 12610,
#  'confidence': 98,
#  'latitude': '-37.4261',
#  'longitude': '147.0323',
#  'surface_temperature_celcius': 83}
# {'_id': 12611,
#  'confidence': 100,
#  'latitude': '-37.3949',
#  'longitude': '147.0175',
#  'surface_temperature_celcius': 91}
# {'_id': 12615,
#  'confidence': 92,
#  'latitude': '-37.6625',
#  'longitude': '144.287',
#  'surface_temperature_celcius': 70}
# {'_id': 12622,
#  'confidence': 97,
#  'latitude': '-37.0155',
#  'longitude': '148.1432',
#  'surface_temperature_celcius': 80}
# {'_id': 12624,
#  'confidence': 94,
#  'latitude': '-36.7152',
#  'longitude': '141.3853',
#  'surface_temperature_celcius': 74}
# {'_id': 12636,
#  'confidence': 90,
#  'latitude': '-34.357',
#  'longitude': '141.5361',
#  'surface_temperature_celcius': 67}
# {'_id': 12637,
#  'confidence': 93,
#  'latitude': '-34.3539',
#  'longitude': '141.5547',
#  'surface_temperature_celcius': 72}
# {'_id': 12638,
#  'confidence': 90,
#  'latitude': '-36.9939',
#  'longitude': '148.2244',
#  'surface_temperature_celcius': 68}
# {'_id': 12640,
#  'confidence': 95,
#  'latitude': '-36.9959',
#  'longitude': '148.2118',
#  'surface_temperature_celcius': 75}
# {'_id': 12641,
#  'confidence': 89,
#  'latitude': '-34.3654',
#  'longitude': '141.543',
#  'surface_temperature_celcius': 65}
# {'_id': 12644,
#  'confidence': 96,
#  'latitude': '-34.3554',
#  'longitude': '141.5413',
#  'surface_temperature_celcius': 79}
# {'_id': 12645,
#  'confidence': 94,
#  'latitude': '-34.3555',
#  'longitude': '141.5495',
#  'surface_temperature_celcius': 75}
# {'_id': 12649,
#  'confidence': 84,
#  'latitude': '-37.0193',
#  'longitude': '148.1459',
#  'surface_temperature_celcius': 71}
# {'_id': 12650,
#  'confidence': 100,
#  'latitude': '-37.4229',
#  'longitude': '147.027',
#  'surface_temperature_celcius': 99}
# {'_id': 12651,
#  'confidence': 80,
#  'latitude': '-37.0055',
#  'longitude': '148.1582',
#  'surface_temperature_celcius': 68}
# {'_id': 12652,
#  'confidence': 85,
#  'latitude': '-37.4128',
#  'longitude': '147.0242',
#  'surface_temperature_celcius': 98}
# {'_id': 12655,
#  'confidence': 94,
#  'latitude': '-37.2284',
#  'longitude': '147.9187',
#  'surface_temperature_celcius': 73}
# {'_id': 12656,
#  'confidence': 97,
#  'latitude': '-37.6572',
#  'longitude': '142.0703',
#  'surface_temperature_celcius': 80}

# %% [markdown]
# ###### Task c: Date, surface temperature (°C), air temperature (°C), relative humidity and max wind speed on 15th and 16th of December 2017.

# %%
result=db['climate_historic'].find({"date":{"$in":['15/12/2017', '16/12/2017']}},{"date":1,"air_temperature_celcius":1 ,"hotspot.surface_temperature_celcius":1,"relative_humidity":1,"max_wind_speed":1})
                                                           
for document in result: 
    pprint(document)
    print('\n')
# Out:
# {'_id': 449,
#  'air_temperature_celcius': '18',
#  'date': '15/12/2017',
#  'hotspot': [{'surface_temperature_celcius': '42'},
#              {'surface_temperature_celcius': '36'},
#              {'surface_temperature_celcius': '38'},
#              {'surface_temperature_celcius': '40'}],
#  'max_wind_speed': '14',
#  'relative_humidity': '52'}
#
#
# {'_id': 450,
#  'air_temperature_celcius': '18',
#  'date': '16/12/2017',
#  'hotspot': [{'surface_temperature_celcius': '43'},
#              {'surface_temperature_celcius': '33'},
#              {'surface_temperature_celcius': '54'},
#              {'surface_temperature_celcius': '73'},
#              {'surface_temperature_celcius': '55'},
#              {'surface_temperature_celcius': '75'},
#              {'surface_temperature_celcius': '55'},
#              {'surface_temperature_celcius': '66'},
#              {'surface_temperature_celcius': '56'},
#              {'surface_temperature_celcius': '60'},
#              {'surface_temperature_celcius': '73'},
#              {'surface_temperature_celcius': '48'},
#              {'surface_temperature_celcius': '55'},
#              {'surface_temperature_celcius': '64'},
#              {'surface_temperature_celcius': '57'}],
#  'max_wind_speed': '13',
#  'relative_humidity': '53.7'}

# %% [markdown]
# ###### Task d: Datetime, air temperature (°C), surface temperature (°C) and confidence when the confidence is between 80 and 100.

# %%
results = db['hotspot_historic'].aggregate([
    {"$lookup":
     {"from": "climate_historic",
      "localField": "date",
      "foreignField" : "date" ,
      "as":"climate_historic"
     }
    },     {"$match" : {"confidence":{"$gte":80,"$lte":100}}},

   {"$project" : {"datetime":1,
                  "surface_temperature_celcius":1, "confidence":1,"climate_historic.air_temperature_celcius":1
                                             }}
])

for document in results:
    pprint(document)
    print('\n')
# Out:
# {'_id': 10002,
#  'climate_historic': [{'air_temperature_celcius': '28'}],
#  'confidence': 82,
#  'datetime': '2017-12-27T00:02:15',
#  'surface_temperature_celcius': 63}
#
#
# {'_id': 10004,
#  'climate_historic': [{'air_temperature_celcius': '28'}],
#  'confidence': 86,
#  'datetime': '2017-12-27T00:02:14',
#  'surface_temperature_celcius': 67}
#
#
# {'_id': 10005,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 80,
#  'datetime': '2017-12-25T04:29:08',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 10008,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 94,
#  'datetime': '2017-12-16T15:38:39',
#  'surface_temperature_celcius': 43}
#
#
# {'_id': 10011,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 93,
#  'datetime': '2017-12-16T04:35:13',
#  'surface_temperature_celcius': 73}
#
#
# {'_id': 10012,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 84,
#  'datetime': '2017-12-16T04:34:58',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10013,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 95,
#  'datetime': '2017-12-16T04:34:58',
#  'surface_temperature_celcius': 75}
#
#
# {'_id': 10015,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 90,
#  'datetime': '2017-12-16T04:34:57',
#  'surface_temperature_celcius': 66}
#
#
# {'_id': 10018,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 93,
#  'datetime': '2017-12-16T00:21:12',
#  'surface_temperature_celcius': 73}
#
#
# {'_id': 10020,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 82,
#  'datetime': '2017-12-16T00:21:11',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10021,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 82,
#  'datetime': '2017-12-16T00:20:53',
#  'surface_temperature_celcius': 64}
#
#
# {'_id': 10023,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 92,
#  'datetime': '2017-12-15T13:17:17',
#  'surface_temperature_celcius': 42}
#
#
# {'_id': 10027,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 92,
#  'datetime': '2017-12-14T04:47:25',
#  'surface_temperature_celcius': 70}
#
#
# {'_id': 10028,
#  'climate_historic': [{'air_temperature_celcius': '28'}],
#  'confidence': 83,
#  'datetime': '2017-12-13T04:04:19',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10032,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 87,
#  'datetime': '2017-12-09T00:14:34',
#  'surface_temperature_celcius': 61}
#
#
# {'_id': 10033,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 81,
#  'datetime': '2017-12-09T00:14:34',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 10034,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 84,
#  'datetime': '2017-12-09T00:14:33',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 10035,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 86,
#  'datetime': '2017-12-09T00:14:33',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10037,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 100,
#  'datetime': '2017-12-08T13:11:44',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 10038,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 100,
#  'datetime': '2017-12-08T13:11:44',
#  'surface_temperature_celcius': 71}
#
#
# {'_id': 10039,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 100,
#  'datetime': '2017-12-08T13:11:43',
#  'surface_temperature_celcius': 52}
#
#
# {'_id': 10042,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 100,
#  'datetime': '2017-11-30T15:38:36',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 10045,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 100,
#  'datetime': '2017-11-30T15:38:35',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 10047,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 100,
#  'datetime': '2017-11-30T15:38:35',
#  'surface_temperature_celcius': 49}
#
#
# {'_id': 10051,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 84,
#  'datetime': '2017-11-30T12:22:15',
#  'surface_temperature_celcius': 38}
#
#
# {'_id': 10052,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 81,
#  'datetime': '2017-11-30T12:22:15',
#  'surface_temperature_celcius': 42}
#
#
# {'_id': 10053,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 100,
#  'datetime': '2017-11-30T12:22:15',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10054,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 100,
#  'datetime': '2017-11-30T12:22:15',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 10055,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 100,
#  'datetime': '2017-11-30T12:22:14',
#  'surface_temperature_celcius': 71}
#
#
# {'_id': 10056,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 84,
#  'datetime': '2017-11-30T04:35:00',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10058,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 98,
#  'datetime': '2017-11-30T04:34:57',
#  'surface_temperature_celcius': 83}
#
#
# {'_id': 10059,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 81,
#  'datetime': '2017-11-30T04:34:57',
#  'surface_temperature_celcius': 57}
#
#
# {'_id': 10060,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 84,
#  'datetime': '2017-11-30T04:34:57',
#  'surface_temperature_celcius': 61}
#
#
# {'_id': 10061,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 99,
#  'datetime': '2017-11-30T04:34:57',
#  'surface_temperature_celcius': 86}
#
#
# {'_id': 10064,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 83,
#  'datetime': '2017-11-30T00:20:53',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 10065,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 87,
#  'datetime': '2017-11-30T00:20:53',
#  'surface_temperature_celcius': 63}
#
#
# {'_id': 10066,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 95,
#  'datetime': '2017-11-30T00:20:53',
#  'surface_temperature_celcius': 76}
#
#
# {'_id': 10067,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 81,
#  'datetime': '2017-11-30T00:20:53',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10069,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 81,
#  'datetime': '2017-11-30T00:20:53',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10073,
#  'climate_historic': [{'air_temperature_celcius': '28'}],
#  'confidence': 100,
#  'datetime': '2017-11-29T13:17:24',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10076,
#  'climate_historic': [{'air_temperature_celcius': '28'}],
#  'confidence': 100,
#  'datetime': '2017-11-29T03:52:10',
#  'surface_temperature_celcius': 87}
#
#
# {'_id': 10078,
#  'climate_historic': [{'air_temperature_celcius': '28'}],
#  'confidence': 97,
#  'datetime': '2017-11-29T03:52:10',
#  'surface_temperature_celcius': 80}
#
#
# {'_id': 10079,
#  'climate_historic': [{'air_temperature_celcius': '28'}],
#  'confidence': 99,
#  'datetime': '2017-11-29T03:52:10',
#  'surface_temperature_celcius': 84}
#
#
# {'_id': 10081,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 84,
#  'datetime': '2017-11-23T04:28:59',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10082,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 93,
#  'datetime': '2017-11-23T04:28:59',
#  'surface_temperature_celcius': 73}
#
#
# {'_id': 10086,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 84,
#  'datetime': '2017-11-22T03:46:00',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10087,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 88,
#  'datetime': '2017-11-22T03:46:00',
#  'surface_temperature_celcius': 64}
#
#
# {'_id': 10088,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 85,
#  'datetime': '2017-11-21T00:27:21',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10089,
#  'climate_historic': [{'air_temperature_celcius': '28'}],
#  'confidence': 87,
#  'datetime': '2017-11-14T04:35:04',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 10092,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 87,
#  'datetime': '2017-11-13T03:52:15',
#  'surface_temperature_celcius': 61}
#
#
# {'_id': 10093,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 81,
#  'datetime': '2017-11-13T03:52:14',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 10101,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 89,
#  'datetime': '2017-11-12T00:33:15',
#  'surface_temperature_celcius': 69}
#
#
# {'_id': 10103,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 80,
#  'datetime': '2017-11-11T13:30:08',
#  'surface_temperature_celcius': 37}
#
#
# {'_id': 10104,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 100,
#  'datetime': '2017-11-11T13:30:08',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10105,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 86,
#  'datetime': '2017-11-11T04:04:25',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10109,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 85,
#  'datetime': '2017-11-09T04:16:48',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10111,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 100,
#  'datetime': '2017-11-09T04:16:48',
#  'surface_temperature_celcius': 93}
#
#
# {'_id': 10112,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 96,
#  'datetime': '2017-11-09T04:16:48',
#  'surface_temperature_celcius': 77}
#
#
# {'_id': 10114,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 87,
#  'datetime': '2017-11-09T04:16:44',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 10115,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 97,
#  'datetime': '2017-11-09T04:16:44',
#  'surface_temperature_celcius': 80}
#
#
# {'_id': 10118,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 83,
#  'datetime': '2017-11-05T04:41:34',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 10120,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 90,
#  'datetime': '2017-11-05T04:41:19',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 10121,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 89,
#  'datetime': '2017-11-05T04:41:19',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 10122,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 81,
#  'datetime': '2017-10-28T03:52:17',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10125,
#  'climate_historic': [{'air_temperature_celcius': '22'}],
#  'confidence': 86,
#  'datetime': '2017-10-27T04:47:31',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10129,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 100,
#  'datetime': '2017-10-26T13:30:31',
#  'surface_temperature_celcius': 48}
#
#
# {'_id': 10130,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 100,
#  'datetime': '2017-10-26T13:30:31',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 10135,
#  'climate_historic': [{'air_temperature_celcius': '12'}],
#  'confidence': 88,
#  'datetime': '2017-10-21T01:09:55',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10137,
#  'climate_historic': [{'air_temperature_celcius': '12'}],
#  'confidence': 92,
#  'datetime': '2017-10-21T01:09:54',
#  'surface_temperature_celcius': 67}
#
#
# {'_id': 10138,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 80,
#  'datetime': '2017-10-20T04:41:19',
#  'surface_temperature_celcius': 46}
#
#
# {'_id': 10139,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 82,
#  'datetime': '2017-10-20T04:41:19',
#  'surface_temperature_celcius': 50}
#
#
# {'_id': 10144,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 84,
#  'datetime': '2017-10-18T00:39:02',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10145,
#  'climate_historic': [{'air_temperature_celcius': '26'}],
#  'confidence': 82,
#  'datetime': '2017-10-18T00:39:02',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10147,
#  'climate_historic': [{'air_temperature_celcius': '22'}],
#  'confidence': 94,
#  'datetime': '2017-10-17T13:36:12',
#  'surface_temperature_celcius': 43}
#
#
# {'_id': 10149,
#  'climate_historic': [{'air_temperature_celcius': '22'}],
#  'confidence': 91,
#  'datetime': '2017-10-17T04:10:45',
#  'surface_temperature_celcius': 68}
#
#
# {'_id': 10151,
#  'climate_historic': [{'air_temperature_celcius': '22'}],
#  'confidence': 82,
#  'datetime': '2017-10-17T04:10:32',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10153,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 100,
#  'datetime': '2017-10-15T04:23:01',
#  'surface_temperature_celcius': 87}
#
#
# {'_id': 10154,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 99,
#  'datetime': '2017-10-15T04:23:01',
#  'surface_temperature_celcius': 85}
#
#
# {'_id': 10157,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 96,
#  'datetime': '2017-10-10T04:04:19',
#  'surface_temperature_celcius': 77}
#
#
# {'_id': 10161,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 91,
#  'datetime': '2017-10-07T12:59:33',
#  'surface_temperature_celcius': 42}
#
#
# {'_id': 10165,
#  'climate_historic': [{'air_temperature_celcius': '19'}],
#  'confidence': 80,
#  'datetime': '2017-10-04T04:41:02',
#  'surface_temperature_celcius': 46}
#
#
# {'_id': 10166,
#  'climate_historic': [{'air_temperature_celcius': '19'}],
#  'confidence': 80,
#  'datetime': '2017-10-04T04:41:00',
#  'surface_temperature_celcius': 46}
#
#
# {'_id': 10167,
#  'climate_historic': [{'air_temperature_celcius': '19'}],
#  'confidence': 85,
#  'datetime': '2017-10-04T04:41:00',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 10168,
#  'climate_historic': [{'air_temperature_celcius': '19'}],
#  'confidence': 88,
#  'datetime': '2017-10-04T04:41:00',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 10170,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 92,
#  'datetime': '2017-10-03T13:23:43',
#  'surface_temperature_celcius': 42}
#
#
# {'_id': 10175,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 90,
#  'datetime': '2017-10-03T03:58:15',
#  'surface_temperature_celcius': 63}
#
#
# {'_id': 10176,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 81,
#  'datetime': '2017-10-03T03:58:15',
#  'surface_temperature_celcius': 48}
#
#
# {'_id': 10177,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 82,
#  'datetime': '2017-10-03T03:58:15',
#  'surface_temperature_celcius': 49}
#
#
# {'_id': 10178,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 84,
#  'datetime': '2017-10-03T03:58:15',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10179,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 90,
#  'datetime': '2017-10-03T03:58:15',
#  'surface_temperature_celcius': 63}
#
#
# {'_id': 10182,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 100,
#  'datetime': '2017-10-03T03:58:14',
#  'surface_temperature_celcius': 90}
#
#
# {'_id': 10183,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 88,
#  'datetime': '2017-10-03T03:58:14',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 10184,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 87,
#  'datetime': '2017-10-03T03:58:14',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10189,
#  'climate_historic': [{'air_temperature_celcius': '11'}],
#  'confidence': 83,
#  'datetime': '2017-10-02T04:53:10',
#  'surface_temperature_celcius': 50}
#
#
# {'_id': 10191,
#  'climate_historic': [{'air_temperature_celcius': '11'}],
#  'confidence': 85,
#  'datetime': '2017-10-02T04:53:09',
#  'surface_temperature_celcius': 61}
#
#
# {'_id': 10195,
#  'climate_historic': [{'air_temperature_celcius': '12'}],
#  'confidence': 100,
#  'datetime': '2017-10-01T15:13:56',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 10198,
#  'climate_historic': [{'air_temperature_celcius': '12'}],
#  'confidence': 84,
#  'datetime': '2017-10-01T04:10:28',
#  'surface_temperature_celcius': 52}
#
#
# {'_id': 10199,
#  'climate_historic': [{'air_temperature_celcius': '12'}],
#  'confidence': 89,
#  'datetime': '2017-10-01T04:10:28',
#  'surface_temperature_celcius': 61}
#
#
# {'_id': 10203,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 82,
#  'datetime': '2017-09-29T04:22:31',
#  'surface_temperature_celcius': 49}
#
#
# {'_id': 10205,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 83,
#  'datetime': '2017-09-27T04:35:36',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10206,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 86,
#  'datetime': '2017-09-27T04:35:36',
#  'surface_temperature_celcius': 60}
# {'_id': 10214,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 100,
#  'datetime': '2017-09-24T15:07:47',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 10217,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 90,
#  'datetime': '2017-09-24T15:07:47',
#  'surface_temperature_celcius': 41}
#
#
# {'_id': 10218,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 99,
#  'datetime': '2017-09-24T15:07:47',
#  'surface_temperature_celcius': 61}
#
#
# {'_id': 10221,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 94,
#  'datetime': '2017-09-24T15:07:45',
#  'surface_temperature_celcius': 43}
#
#
# {'_id': 10222,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 100,
#  'datetime': '2017-09-24T15:07:45',
#  'surface_temperature_celcius': 61}
#
#
# {'_id': 10223,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 100,
#  'datetime': '2017-09-24T13:30:10',
#  'surface_temperature_celcius': 47}
#
#
# {'_id': 10225,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 82,
#  'datetime': '2017-09-24T13:30:09',
#  'surface_temperature_celcius': 38}
#
#
# {'_id': 10226,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 100,
#  'datetime': '2017-09-24T13:30:09',
#  'surface_temperature_celcius': 48}
#
#
# {'_id': 10227,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 100,
#  'datetime': '2017-09-24T13:30:09',
#  'surface_temperature_celcius': 48}
#
#
# {'_id': 10228,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 84,
#  'datetime': '2017-09-24T13:30:07',
#  'surface_temperature_celcius': 50}
#
#
# {'_id': 10229,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 100,
#  'datetime': '2017-09-24T04:04:19',
#  'surface_temperature_celcius': 88}
#
#
# {'_id': 10234,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 86,
#  'datetime': '2017-09-24T04:04:18',
#  'surface_temperature_celcius': 76}
#
#
# {'_id': 10238,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 84,
#  'datetime': '2017-09-24T04:04:04',
#  'surface_temperature_celcius': 52}
#
#
# {'_id': 10241,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 86,
#  'datetime': '2017-09-23T23:50:44',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10245,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 100,
#  'datetime': '2017-09-23T12:47:12',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10246,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 100,
#  'datetime': '2017-09-23T12:47:12',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 10247,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 100,
#  'datetime': '2017-09-23T12:47:12',
#  'surface_temperature_celcius': 48}
#
#
# {'_id': 10248,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 100,
#  'datetime': '2017-09-23T12:47:12',
#  'surface_temperature_celcius': 52}
#
#
# {'_id': 10249,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 100,
#  'datetime': '2017-09-23T12:47:12',
#  'surface_temperature_celcius': 50}
#
#
# {'_id': 10251,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 100,
#  'datetime': '2017-09-23T12:47:12',
#  'surface_temperature_celcius': 84}
#
#
# {'_id': 10252,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 100,
#  'datetime': '2017-09-23T12:47:12',
#  'surface_temperature_celcius': 79}
#
#
# {'_id': 10254,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 88,
#  'datetime': '2017-09-23T04:59:13',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10256,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 87,
#  'datetime': '2017-09-23T04:59:11',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10257,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 80,
#  'datetime': '2017-09-23T04:59:11',
#  'surface_temperature_celcius': 50}
#
#
# {'_id': 10267,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 89,
#  'datetime': '2017-09-20T04:29:03',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10268,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 100,
#  'datetime': '2017-09-20T04:29:03',
#  'surface_temperature_celcius': 112}
#
#
# {'_id': 10270,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 88,
#  'datetime': '2017-09-20T04:28:45',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10271,
#  'climate_historic': [{'air_temperature_celcius': '11'}],
#  'confidence': 80,
#  'datetime': '2017-09-10T04:00:00',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 10272,
#  'climate_historic': [{'air_temperature_celcius': '11'}],
#  'confidence': 84,
#  'datetime': '2017-09-10T03:53:00',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 10273,
#  'climate_historic': [{'air_temperature_celcius': '11'}],
#  'confidence': 86,
#  'datetime': '2017-09-10T03:50:30',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10274,
#  'climate_historic': [{'air_temperature_celcius': '11'}],
#  'confidence': 81,
#  'datetime': '2017-09-10T03:50:10',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 10281,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 87,
#  'datetime': '2017-08-13T05:08:00',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 10283,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 80,
#  'datetime': '2017-08-13T05:05:10',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 10288,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 83,
#  'datetime': '2017-08-13T05:02:30',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10291,
#  'climate_historic': [{'air_temperature_celcius': '5'}],
#  'confidence': 94,
#  'datetime': '2017-08-02T03:45:40',
#  'surface_temperature_celcius': 87}
#
#
# {'_id': 10293,
#  'climate_historic': [{'air_temperature_celcius': '7'}],
#  'confidence': 89,
#  'datetime': '2017-08-01T00:20:30',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 10295,
#  'climate_historic': [{'air_temperature_celcius': '7'}],
#  'confidence': 100,
#  'datetime': '2017-07-31T13:21:00',
#  'surface_temperature_celcius': 51}
#
#
# {'_id': 10296,
#  'climate_historic': [{'air_temperature_celcius': '7'}],
#  'confidence': 92,
#  'datetime': '2017-07-31T13:21:00',
#  'surface_temperature_celcius': 43}
#
#
# {'_id': 10301,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 83,
#  'datetime': '2017-07-06T04:08:00',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10302,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 91,
#  'datetime': '2017-07-06T04:02:00',
#  'surface_temperature_celcius': 69}
#
#
# {'_id': 10306,
#  'climate_historic': [{'air_temperature_celcius': '6'}],
#  'confidence': 84,
#  'datetime': '2017-07-02T04:29:18',
#  'surface_temperature_celcius': 52}
#
#
# {'_id': 10307,
#  'climate_historic': [{'air_temperature_celcius': '6'}],
#  'confidence': 84,
#  'datetime': '2017-07-02T04:29:18',
#  'surface_temperature_celcius': 52}
#
#
# {'_id': 10310,
#  'climate_historic': [{'air_temperature_celcius': '6'}],
#  'confidence': 88,
#  'datetime': '2017-07-02T04:29:00',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 10311,
#  'climate_historic': [{'air_temperature_celcius': '6'}],
#  'confidence': 88,
#  'datetime': '2017-07-02T04:29:00',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 10320,
#  'climate_historic': [{'air_temperature_celcius': '5'}],
#  'confidence': 81,
#  'datetime': '2017-06-30T00:27:19',
#  'surface_temperature_celcius': 48}
#
#
# {'_id': 10323,
#  'climate_historic': [{'air_temperature_celcius': '5'}],
#  'confidence': 81,
#  'datetime': '2017-06-30T00:27:19',
#  'surface_temperature_celcius': 48}
#
#
# {'_id': 10327,
#  'climate_historic': [{'air_temperature_celcius': '11'}],
#  'confidence': 91,
#  'datetime': '2017-06-20T04:02:00',
#  'surface_temperature_celcius': 68}
#
#
# {'_id': 10328,
#  'climate_historic': [{'air_temperature_celcius': '11'}],
#  'confidence': 100,
#  'datetime': '2017-06-20T04:02:00',
#  'surface_temperature_celcius': 88}
#
#
# {'_id': 10329,
#  'climate_historic': [{'air_temperature_celcius': '11'}],
#  'confidence': 97,
#  'datetime': '2017-06-20T04:02:00',
#  'surface_temperature_celcius': 80}
#
#
# {'_id': 10330,
#  'climate_historic': [{'air_temperature_celcius': '11'}],
#  'confidence': 100,
#  'datetime': '2017-06-20T04:02:00',
#  'surface_temperature_celcius': 89}
#
#
# {'_id': 10336,
#  'climate_historic': [{'air_temperature_celcius': '11'}],
#  'confidence': 94,
#  'datetime': '2017-06-14T04:43:00',
#  'surface_temperature_celcius': 85}
#
#
# {'_id': 10343,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 84,
#  'datetime': '2017-06-09T04:23:20',
#  'surface_temperature_celcius': 52}
#
#
# {'_id': 10344,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 86,
#  'datetime': '2017-06-09T04:23:16',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10347,
#  'climate_historic': [{'air_temperature_celcius': '8'}],
#  'confidence': 86,
#  'datetime': '2017-06-07T04:35:50',
#  'surface_temperature_celcius': 61}
#
#
# {'_id': 10350,
#  'climate_historic': [{'air_temperature_celcius': '8'}],
#  'confidence': 96,
#  'datetime': '2017-06-07T04:33:50',
#  'surface_temperature_celcius': 78}
#
#
# {'_id': 10351,
#  'climate_historic': [{'air_temperature_celcius': '8'}],
#  'confidence': 85,
#  'datetime': '2017-06-07T04:32:10',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10354,
#  'climate_historic': [{'air_temperature_celcius': '8'}],
#  'confidence': 81,
#  'datetime': '2017-06-07T04:32:10',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 10357,
#  'climate_historic': [{'air_temperature_celcius': '8'}],
#  'confidence': 85,
#  'datetime': '2017-06-07T04:32:10',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10358,
#  'climate_historic': [{'air_temperature_celcius': '8'}],
#  'confidence': 90,
#  'datetime': '2017-06-07T04:32:10',
#  'surface_temperature_celcius': 67}
#
#
# {'_id': 10360,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 86,
#  'datetime': '2017-06-04T04:08:20',
#  'surface_temperature_celcius': 61}
#
#
# {'_id': 10361,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 91,
#  'datetime': '2017-06-04T04:08:10',
#  'surface_temperature_celcius': 69}
#
#
# {'_id': 10364,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 91,
#  'datetime': '2017-06-04T04:02:10',
#  'surface_temperature_celcius': 68}
#
#
# {'_id': 10365,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 85,
#  'datetime': '2017-06-04T04:02:10',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10377,
#  'climate_historic': [{'air_temperature_celcius': '12'}],
#  'confidence': 83,
#  'datetime': '2017-06-02T04:14:10',
#  'surface_temperature_celcius': 57}
#
#
# {'_id': 10378,
#  'climate_historic': [{'air_temperature_celcius': '12'}],
#  'confidence': 83,
#  'datetime': '2017-06-02T04:14:10',
#  'surface_temperature_celcius': 57}
#
#
# {'_id': 10382,
#  'climate_historic': [{'air_temperature_celcius': '11'}],
#  'confidence': 82,
#  'datetime': '2017-06-01T05:09:20',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10386,
#  'climate_historic': [{'air_temperature_celcius': '13'}],
#  'confidence': 85,
#  'datetime': '2017-05-26T04:08:10',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10391,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 84,
#  'datetime': '2017-05-23T00:58:00',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10394,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 81,
#  'datetime': '2017-05-23T00:54:50',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10396,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 80,
#  'datetime': '2017-05-22T04:43:30',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 10402,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 100,
#  'datetime': '2017-05-22T04:34:10',
#  'surface_temperature_celcius': 101}
#
#
# {'_id': 10412,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 91,
#  'datetime': '2017-05-22T04:32:20',
#  'surface_temperature_celcius': 68}
#
#
# {'_id': 10414,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 96,
#  'datetime': '2017-05-22T04:32:20',
#  'surface_temperature_celcius': 78}
#
#
# {'_id': 10417,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 98,
#  'datetime': '2017-05-22T04:32:20',
#  'surface_temperature_celcius': 82}
#
#
# {'_id': 10420,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 100,
#  'datetime': '2017-05-22T04:32:20',
#  'surface_temperature_celcius': 93}
#
#
# {'_id': 10421,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 89,
#  'datetime': '2017-05-22T04:32:20',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 10422,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 85,
#  'datetime': '2017-05-22T00:15:00',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10426,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 100,
#  'datetime': '2017-05-22T00:13:00',
#  'surface_temperature_celcius': 90}
#
#
# {'_id': 10427,
#  'climate_historic': [{'air_temperature_celcius': '17'}],
#  'confidence': 89,
#  'datetime': '2017-05-22T00:13:00',
#  'surface_temperature_celcius': 64}
#
#
# {'_id': 10442,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 93,
#  'datetime': '2017-05-15T04:34:30',
#  'surface_temperature_celcius': 73}
#
#
# {'_id': 10443,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 96,
#  'datetime': '2017-05-15T04:34:30',
#  'surface_temperature_celcius': 78}
#
#
# {'_id': 10447,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 83,
#  'datetime': '2017-05-15T04:33:00',
#  'surface_temperature_celcius': 57}
#
#
# {'_id': 10448,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 92,
#  'datetime': '2017-05-15T04:33:00',
#  'surface_temperature_celcius': 70}
#
#
# {'_id': 10453,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 100,
#  'datetime': '2017-05-15T04:32:50',
#  'surface_temperature_celcius': 101}
#
#
# {'_id': 10454,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 84,
#  'datetime': '2017-05-15T04:32:50',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 10455,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 96,
#  'datetime': '2017-05-15T04:31:20',
#  'surface_temperature_celcius': 77}
#
#
# {'_id': 10456,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 87,
#  'datetime': '2017-05-15T04:31:10',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 10457,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 86,
#  'datetime': '2017-05-15T04:30:00',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10458,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 83,
#  'datetime': '2017-05-15T04:29:50',
#  'surface_temperature_celcius': 63}
#
#
# {'_id': 10459,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 84,
#  'datetime': '2017-05-15T04:29:50',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 10469,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 100,
#  'datetime': '2017-05-15T04:28:00',
#  'surface_temperature_celcius': 94}
#
#
# {'_id': 10472,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 87,
#  'datetime': '2017-05-15T04:28:00',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 10473,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 100,
#  'datetime': '2017-05-15T04:28:00',
#  'surface_temperature_celcius': 87}
#
#
# {'_id': 10474,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 90,
#  'datetime': '2017-05-15T04:27:50',
#  'surface_temperature_celcius': 66}
#
#
# {'_id': 10488,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 84,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 57}
#
#
# {'_id': 10489,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 96,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 77}
#
#
# {'_id': 10493,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 80,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 10494,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 89,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 10496,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 100,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 111}
#
#
# {'_id': 10500,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 83,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10504,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 82,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10506,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 85,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 66}
#
#
# {'_id': 10508,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 90,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 78}
#
#
# {'_id': 10511,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 86,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10514,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 82,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10517,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 83,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10518,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 86,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 61}
#
#
# {'_id': 10520,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 90,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 67}
#
#
# {'_id': 10521,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 94,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 74}
#
#
# {'_id': 10522,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 100,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 110}
#
#
# {'_id': 10524,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 89,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 10527,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 95,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 76}
#
#
# {'_id': 10531,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 81,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 10532,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 94,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 74}
#
#
# {'_id': 10533,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 86,
#  'datetime': '2017-05-15T04:26:20',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10539,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 100,
#  'datetime': '2017-05-15T00:12:10',
#  'surface_temperature_celcius': 90}
#
#
# {'_id': 10542,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 100,
#  'datetime': '2017-05-13T04:45:40',
#  'surface_temperature_celcius': 102}
#
#
# {'_id': 10544,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 95,
#  'datetime': '2017-05-13T04:43:30',
#  'surface_temperature_celcius': 77}
#
#
# {'_id': 10549,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 100,
#  'datetime': '2017-05-13T04:41:50',
#  'surface_temperature_celcius': 98}
#
#
# {'_id': 10552,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 100,
#  'datetime': '2017-05-13T04:40:20',
#  'surface_temperature_celcius': 120}
#
#
# {'_id': 10553,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 100,
#  'datetime': '2017-05-13T04:40:10',
#  'surface_temperature_celcius': 90}
#
#
# {'_id': 10555,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 81,
#  'datetime': '2017-05-13T04:39:50',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10556,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 83,
#  'datetime': '2017-05-13T04:39:30',
#  'surface_temperature_celcius': 63}
#
#
# {'_id': 10559,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 85,
#  'datetime': '2017-05-13T04:39:00',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10561,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 100,
#  'datetime': '2017-05-13T04:38:50',
#  'surface_temperature_celcius': 93}
#
#
# {'_id': 10563,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 87,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 10565,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 81,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 10568,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 86,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10569,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 84,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 57}
#
#
# {'_id': 10570,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 85,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10571,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 87,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 10572,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 84,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 10573,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 94,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 75}
#
#
# {'_id': 10575,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 100,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 113}
#
#
# {'_id': 10579,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 82,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10580,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 91,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 69}
#
#
# {'_id': 10583,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 91,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 69}
#
#
# {'_id': 10584,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 82,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10586,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 90,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 68}
#
#
# {'_id': 10591,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 100,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 95}
#
#
# {'_id': 10592,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 86,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10594,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 85,
#  'datetime': '2017-05-13T04:38:40',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10597,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 83,
#  'datetime': '2017-05-12T03:57:40',
#  'surface_temperature_celcius': 57}
#
#
# {'_id': 10600,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 93,
#  'datetime': '2017-05-12T03:56:10',
#  'surface_temperature_celcius': 73}
#
#
# {'_id': 10603,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 87,
#  'datetime': '2017-05-12T03:56:10',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 10606,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 90,
#  'datetime': '2017-05-11T04:57:20',
#  'surface_temperature_celcius': 67}
#
#
# {'_id': 10607,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 96,
#  'datetime': '2017-05-11T04:57:20',
#  'surface_temperature_celcius': 79}
#
#
# {'_id': 10608,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 88,
#  'datetime': '2017-05-11T04:54:00',
#  'surface_temperature_celcius': 63}
#
#
# {'_id': 10609,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 89,
#  'datetime': '2017-05-11T04:51:00',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 10610,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 84,
#  'datetime': '2017-05-11T04:50:40',
#  'surface_temperature_celcius': 78}
#
#
# {'_id': 10612,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 94,
#  'datetime': '2017-05-11T04:50:40',
#  'surface_temperature_celcius': 75}
#
#
# {'_id': 10614,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 92,
#  'datetime': '2017-05-11T04:50:40',
#  'surface_temperature_celcius': 70}
#
#
# {'_id': 10617,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 99,
#  'datetime': '2017-05-11T04:50:40',
#  'surface_temperature_celcius': 86}
#
#
# {'_id': 10618,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 91,
#  'datetime': '2017-05-11T04:50:40',
#  'surface_temperature_celcius': 69}
#
#
# {'_id': 10620,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 97,
#  'datetime': '2017-05-11T04:50:40',
#  'surface_temperature_celcius': 81}
#
#
# {'_id': 10621,
#  'climate_historic': [{'air_temperature_celcius': '9'}],
#  'confidence': 80,
#  'datetime': '2017-05-11T04:50:40',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 10625,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 96,
#  'datetime': '2017-05-10T04:16:30',
#  'surface_temperature_celcius': 77}
#
#
# {'_id': 10627,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 84,
#  'datetime': '2017-05-10T04:16:10',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 10630,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 88,
#  'datetime': '2017-05-10T04:14:20',
#  'surface_temperature_celcius': 64}
#
#
# {'_id': 10633,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 100,
#  'datetime': '2017-05-10T04:14:10',
#  'surface_temperature_celcius': 103}
#
#
# {'_id': 10636,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 87,
#  'datetime': '2017-05-10T04:12:50',
#  'surface_temperature_celcius': 63}
#
#
# {'_id': 10637,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 86,
#  'datetime': '2017-05-10T04:12:50',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10639,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 83,
#  'datetime': '2017-05-10T04:11:30',
#  'surface_temperature_celcius': 57}
#
#
# {'_id': 10641,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 84,
#  'datetime': '2017-05-10T04:11:10',
#  'surface_temperature_celcius': 68}
#
#
# {'_id': 10643,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 81,
#  'datetime': '2017-05-10T04:11:10',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10655,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 82,
#  'datetime': '2017-05-10T04:08:50',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10657,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 98,
#  'datetime': '2017-05-10T04:08:50',
#  'surface_temperature_celcius': 83}
#
#
# {'_id': 10658,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 98,
#  'datetime': '2017-05-10T04:08:50',
#  'surface_temperature_celcius': 82}
#
#
# {'_id': 10659,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 82,
#  'datetime': '2017-05-10T04:08:50',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10660,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 92,
#  'datetime': '2017-05-10T04:08:50',
#  'surface_temperature_celcius': 70}
#
#
# {'_id': 10661,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 84,
#  'datetime': '2017-05-10T04:08:30',
#  'surface_temperature_celcius': 57}
#
#
# {'_id': 10663,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 86,
#  'datetime': '2017-05-10T04:08:30',
#  'surface_temperature_celcius': 61}
#
#
# {'_id': 10664,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 83,
#  'datetime': '2017-05-10T04:08:30',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 10671,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 95,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 76}
#
#
# {'_id': 10674,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 85,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 10676,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 80,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 10677,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 99,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 84}
#
#
# {'_id': 10678,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 96,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 78}
#
#
# {'_id': 10679,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 92,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 71}
#
#
# {'_id': 10681,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 80,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 10682,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 100,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 89}
#
#
# {'_id': 10686,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 80,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 10687,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 100,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 113}
#
#
# {'_id': 10691,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 81,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10693,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 86,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 10694,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 80,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 10695,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 81,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 10699,
#  'climate_historic': [{'air_temperature_celcius': '10'}],
#  'confidence': 87,
#  'datetime': '2017-05-10T04:08:10',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 10701,
# ...
#  'surface_temperature_celcius': 72}
#
#
# {'_id': 12466,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 95,
#  'datetime': '2017-04-03T03:50:40',
#  'surface_temperature_celcius': 76}
#
#
# {'_id': 12467,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 86,
#  'datetime': '2017-04-03T03:50:40',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 12469,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 89,
#  'datetime': '2017-04-03T03:50:40',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 12471,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 82,
#  'datetime': '2017-04-03T03:50:40',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 12472,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 89,
#  'datetime': '2017-04-03T03:50:40',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 12476,
#  'climate_historic': [{'air_temperature_celcius': '15'}],
#  'confidence': 81,
#  'datetime': '2017-04-03T01:07:20',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 12490,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 82,
#  'datetime': '2017-03-31T05:07:10',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 12491,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 87,
#  'datetime': '2017-03-31T05:01:20',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 12494,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 82,
#  'datetime': '2017-03-31T04:58:30',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 12498,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 80,
#  'datetime': '2017-03-31T04:58:00',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 12504,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 86,
#  'datetime': '2017-03-31T04:57:10',
#  'surface_temperature_celcius': 61}
#
#
# {'_id': 12510,
#  'climate_historic': [{'air_temperature_celcius': '14'}],
#  'confidence': 81,
#  'datetime': '2017-03-31T00:36:30',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 12513,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 88,
#  'datetime': '2017-03-28T04:38:00',
#  'surface_temperature_celcius': 64}
#
#
# {'_id': 12515,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 86,
#  'datetime': '2017-03-28T04:33:40',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 12516,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 92,
#  'datetime': '2017-03-28T04:33:30',
#  'surface_temperature_celcius': 71}
#
#
# {'_id': 12517,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 95,
#  'datetime': '2017-03-28T04:33:30',
#  'surface_temperature_celcius': 76}
#
#
# {'_id': 12519,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 93,
#  'datetime': '2017-03-28T04:32:20',
#  'surface_temperature_celcius': 73}
#
#
# {'_id': 12522,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 83,
#  'datetime': '2017-03-28T04:30:50',
#  'surface_temperature_celcius': 56}
#
#
# {'_id': 12523,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 80,
#  'datetime': '2017-03-28T04:30:20',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 12524,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 94,
#  'datetime': '2017-03-28T04:30:10',
#  'surface_temperature_celcius': 74}
#
#
# {'_id': 12527,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 98,
#  'datetime': '2017-03-28T04:30:10',
#  'surface_temperature_celcius': 82}
#
#
# {'_id': 12528,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 81,
#  'datetime': '2017-03-28T04:30:10',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 12529,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 97,
#  'datetime': '2017-03-28T04:30:10',
#  'surface_temperature_celcius': 80}
#
#
# {'_id': 12532,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 81,
#  'datetime': '2017-03-28T04:28:30',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 12534,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 88,
#  'datetime': '2017-03-28T04:28:30',
#  'surface_temperature_celcius': 63}
#
#
# {'_id': 12535,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 87,
#  'datetime': '2017-03-28T04:28:30',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 12537,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 97,
#  'datetime': '2017-03-28T04:27:40',
#  'surface_temperature_celcius': 80}
#
#
# {'_id': 12538,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 100,
#  'datetime': '2017-03-28T04:27:20',
#  'surface_temperature_celcius': 107}
#
#
# {'_id': 12541,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 100,
#  'datetime': '2017-03-28T04:27:10',
#  'surface_temperature_celcius': 108}
#
#
# {'_id': 12542,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 82,
#  'datetime': '2017-03-28T04:27:00',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 12543,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 99,
#  'datetime': '2017-03-28T04:27:00',
#  'surface_temperature_celcius': 86}
#
#
# {'_id': 12546,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 81,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 12547,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 80,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 12548,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 83,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 57}
#
#
# {'_id': 12549,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 100,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 90}
#
#
# {'_id': 12552,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 87,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 12553,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 97,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 81}
#
#
# {'_id': 12554,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 85,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 12555,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 88,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 63}
#
#
# {'_id': 12556,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 87,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 12557,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 84,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 12561,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 97,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 81}
#
#
# {'_id': 12563,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 83,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 57}
#
#
# {'_id': 12565,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 85,
#  'datetime': '2017-03-28T04:26:50',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 12569,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 81,
#  'datetime': '2017-03-26T04:43:20',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 12571,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 80,
#  'datetime': '2017-03-26T04:40:50',
#  'surface_temperature_celcius': 53}
#
#
# {'_id': 12573,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 81,
#  'datetime': '2017-03-26T04:39:50',
#  'surface_temperature_celcius': 54}
#
#
# {'_id': 12575,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 91,
#  'datetime': '2017-03-26T04:39:10',
#  'surface_temperature_celcius': 68}
#
#
# {'_id': 12576,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 92,
#  'datetime': '2017-03-26T04:39:10',
#  'surface_temperature_celcius': 70}
#
#
# {'_id': 12577,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 100,
#  'datetime': '2017-03-26T04:39:10',
#  'surface_temperature_celcius': 89}
#
#
# {'_id': 12578,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 82,
#  'datetime': '2017-03-26T04:39:10',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 12579,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 87,
#  'datetime': '2017-03-26T04:39:10',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 12581,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 84,
#  'datetime': '2017-03-26T04:39:10',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 12587,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 82,
#  'datetime': '2017-03-25T03:59:50',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 12588,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 87,
#  'datetime': '2017-03-25T03:58:10',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 12589,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 95,
#  'datetime': '2017-03-25T03:58:10',
#  'surface_temperature_celcius': 75}
#
#
# {'_id': 12590,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 85,
#  'datetime': '2017-03-25T03:57:10',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 12591,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 100,
#  'datetime': '2017-03-25T03:57:10',
#  'surface_temperature_celcius': 111}
#
#
# {'_id': 12592,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 95,
#  'datetime': '2017-03-25T03:57:10',
#  'surface_temperature_celcius': 77}
#
#
# {'_id': 12594,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 100,
#  'datetime': '2017-03-25T03:56:40',
#  'surface_temperature_celcius': 99}
#
#
# {'_id': 12599,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 85,
#  'datetime': '2017-03-19T04:39:50',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 12601,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 96,
#  'datetime': '2017-03-19T04:39:20',
#  'surface_temperature_celcius': 79}
#
#
# {'_id': 12604,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 90,
#  'datetime': '2017-03-19T04:36:00',
#  'surface_temperature_celcius': 66}
#
#
# {'_id': 12610,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 98,
#  'datetime': '2017-03-19T04:33:00',
#  'surface_temperature_celcius': 83}
#
#
# {'_id': 12611,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 100,
#  'datetime': '2017-03-19T04:32:50',
#  'surface_temperature_celcius': 91}
#
#
# {'_id': 12612,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 84,
#  'datetime': '2017-03-19T04:32:50',
#  'surface_temperature_celcius': 58}
#
#
# {'_id': 12614,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 100,
#  'datetime': '2017-03-19T04:32:40',
#  'surface_temperature_celcius': 113}
#
#
# {'_id': 12615,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 92,
#  'datetime': '2017-03-19T04:32:40',
#  'surface_temperature_celcius': 70}
#
#
# {'_id': 12616,
#  'climate_historic': [{'air_temperature_celcius': '24'}],
#  'confidence': 100,
#  'datetime': '2017-03-19T04:32:40',
#  'surface_temperature_celcius': 106}
#
#
# {'_id': 12621,
#  'climate_historic': [{'air_temperature_celcius': '21'}],
#  'confidence': 100,
#  'datetime': '2017-03-18T03:50:50',
#  'surface_temperature_celcius': 121}
#
#
# {'_id': 12622,
#  'climate_historic': [{'air_temperature_celcius': '21'}],
#  'confidence': 97,
#  'datetime': '2017-03-18T03:50:40',
#  'surface_temperature_celcius': 80}
#
#
# {'_id': 12624,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 94,
#  'datetime': '2017-03-17T04:48:20',
#  'surface_temperature_celcius': 74}
#
#
# {'_id': 12626,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 84,
#  'datetime': '2017-03-17T04:45:10',
#  'surface_temperature_celcius': 59}
#
#
# {'_id': 12628,
#  'climate_historic': [{'air_temperature_celcius': '18'}],
#  'confidence': 86,
#  'datetime': '2017-03-17T04:45:00',
#  'surface_temperature_celcius': 60}
#
#
# {'_id': 12636,
#  'climate_historic': [{'air_temperature_celcius': '25'}],
#  'confidence': 90,
#  'datetime': '2017-03-14T04:24:40',
#  'surface_temperature_celcius': 67}
#
#
# {'_id': 12637,
#  'climate_historic': [{'air_temperature_celcius': '25'}],
#  'confidence': 93,
#  'datetime': '2017-03-14T04:22:20',
#  'surface_temperature_celcius': 72}
#
#
# {'_id': 12638,
#  'climate_historic': [{'air_temperature_celcius': '25'}],
#  'confidence': 90,
#  'datetime': '2017-03-14T04:20:50',
#  'surface_temperature_celcius': 68}
#
#
# {'_id': 12640,
#  'climate_historic': [{'air_temperature_celcius': '25'}],
#  'confidence': 95,
#  'datetime': '2017-03-14T04:16:30',
#  'surface_temperature_celcius': 75}
#
#
# {'_id': 12641,
#  'climate_historic': [{'air_temperature_celcius': '25'}],
#  'confidence': 89,
#  'datetime': '2017-03-14T04:16:20',
#  'surface_temperature_celcius': 65}
#
#
# {'_id': 12643,
#  'climate_historic': [{'air_temperature_celcius': '25'}],
#  'confidence': 81,
#  'datetime': '2017-03-14T04:14:40',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 12644,
#  'climate_historic': [{'air_temperature_celcius': '25'}],
#  'confidence': 96,
#  'datetime': '2017-03-14T04:14:30',
#  'surface_temperature_celcius': 79}
#
#
# {'_id': 12645,
#  'climate_historic': [{'air_temperature_celcius': '25'}],
#  'confidence': 94,
#  'datetime': '2017-03-14T04:14:30',
#  'surface_temperature_celcius': 75}
#
#
# {'_id': 12648,
#  'climate_historic': [{'air_temperature_celcius': '21'}],
#  'confidence': 94,
#  'datetime': '2017-03-12T04:33:50',
#  'surface_temperature_celcius': 105}
#
#
# {'_id': 12649,
#  'climate_historic': [{'air_temperature_celcius': '21'}],
#  'confidence': 84,
#  'datetime': '2017-03-12T04:29:50',
#  'surface_temperature_celcius': 71}
#
#
# {'_id': 12650,
#  'climate_historic': [{'air_temperature_celcius': '21'}],
#  'confidence': 100,
#  'datetime': '2017-03-12T04:28:20',
#  'surface_temperature_celcius': 99}
#
#
# {'_id': 12651,
#  'climate_historic': [{'air_temperature_celcius': '21'}],
#  'confidence': 80,
#  'datetime': '2017-03-12T04:28:00',
#  'surface_temperature_celcius': 68}
#
#
# {'_id': 12652,
#  'climate_historic': [{'air_temperature_celcius': '21'}],
#  'confidence': 85,
#  'datetime': '2017-03-12T04:27:20',
#  'surface_temperature_celcius': 98}
#
#
# {'_id': 12653,
#  'climate_historic': [{'air_temperature_celcius': '19'}],
#  'confidence': 100,
#  'datetime': '2017-03-10T04:48:40',
#  'surface_temperature_celcius': 105}
#
#
# {'_id': 12654,
#  'climate_historic': [{'air_temperature_celcius': '19'}],
#  'confidence': 100,
#  'datetime': '2017-03-10T04:46:20',
#  'surface_temperature_celcius': 109}
#
#
# {'_id': 12655,
#  'climate_historic': [{'air_temperature_celcius': '19'}],
#  'confidence': 94,
#  'datetime': '2017-03-10T04:45:30',
#  'surface_temperature_celcius': 73}
#
#
# {'_id': 12656,
#  'climate_historic': [{'air_temperature_celcius': '19'}],
#  'confidence': 97,
#  'datetime': '2017-03-10T04:45:30',
#  'surface_temperature_celcius': 80}
#
#
# {'_id': 12657,
#  'climate_historic': [{'air_temperature_celcius': '19'}],
#  'confidence': 81,
#  'datetime': '2017-03-10T04:43:50',
#  'surface_temperature_celcius': 55}
#
#
# {'_id': 12661,
#  'climate_historic': [{'air_temperature_celcius': '23'}],
#  'confidence': 86,
#  'datetime': '2017-03-09T13:23:40',
#  'surface_temperature_celcius': 41}
#
#
# {'_id': 12666,
#  'climate_historic': [{'air_temperature_celcius': '19'}],
#  'confidence': 88,
#  'datetime': '2017-03-07T04:16:10',
#  'surface_temperature_celcius': 64}
#
#
# {'_id': 12667,
#  'climate_historic': [{'air_temperature_celcius': '20'}],
#  'confidence': 87,
#  'datetime': '2017-03-06T05:06:30',
#  'surface_temperature_celcius': 62}
#
#
# {'_id': 12668,
#  'climate_historic': [{'air_temperature_celcius': '20'}],
#  'confidence': 85,
#  'datetime': '2017-03-06T05:06:20',
#  'surface_temperature_celcius': 59}

# %% [markdown]
# ###### Task e:  Top 10 records with the highest surface temperature (°C).

# %%
result=db['hotspot_historic'].find().sort("surface_temperature_celcius", pymongo.DESCENDING).limit(10)

# {"date":{"$in":['15/12/2017', '16/12/2017']}},{"date":1,"air_temperature_celcius":1 ,"hotspot.surface_temperature_celcius":1,"relative_humidity":1,"max_wind_speed":1})
                                                           
for document in result: 
    pprint(document)
    print('\n')
# Out:
# {'_id': 11188,
#  'confidence': 100,
#  'date': '18/04/2017',
#  'datetime': '2017-04-18T04:52:00',
#  'latitude': '-38.1665',
#  'longitude': '143.062',
#  'owner': 208,
#  'surface_temperature_celcius': 124}
#
#
# {'_id': 12382,
#  'confidence': 100,
#  'date': '4/04/2017',
#  'datetime': '2017-04-04T04:32:50',
#  'latitude': '-36.343',
#  'longitude': '142.1986',
#  'owner': 194,
#  'surface_temperature_celcius': 123}
#
#
# {'_id': 11046,
#  'confidence': 100,
#  'date': '1/05/2017',
#  'datetime': '2017-05-01T04:14:20',
#  'latitude': '-36.9318',
#  'longitude': '143.0907',
#  'owner': 221,
#  'surface_temperature_celcius': 122}
#
#
# {'_id': 12621,
#  'confidence': 100,
#  'date': '18/03/2017',
#  'datetime': '2017-03-18T03:50:50',
#  'latitude': '-37.017',
#  'longitude': '148.1297',
#  'owner': 177,
#  'surface_temperature_celcius': 121}
#
#
# {'_id': 10552,
#  'confidence': 100,
#  'date': '13/05/2017',
#  'datetime': '2017-05-13T04:40:20',
#  'latitude': '-34.9938',
#  'longitude': '141.876',
#  'owner': 233,
#  'surface_temperature_celcius': 120}
#
#
# {'_id': 11341,
#  'confidence': 100,
#  'date': '18/04/2017',
#  'datetime': '2017-04-18T04:44:50',
#  'latitude': '-37.8326',
#  'longitude': '143.4999',
#  'owner': 208,
#  'surface_temperature_celcius': 120}
#
#
# {'_id': 11728,
#  'confidence': 100,
#  'date': '13/04/2017',
#  'datetime': '2017-04-13T04:28:10',
#  'latitude': '-37.0745',
#  'longitude': '141.0692',
#  'owner': 203,
#  'surface_temperature_celcius': 120}
#
#
# {'_id': 12325,
#  'confidence': 100,
#  'date': '4/04/2017',
#  'datetime': '2017-04-04T04:40:00',
#  'latitude': '-36.1057',
#  'longitude': '141.7608',
#  'owner': 194,
#  'surface_temperature_celcius': 120}
#
#
# {'_id': 12389,
#  'confidence': 100,
#  'date': '4/04/2017',
#  'datetime': '2017-04-04T04:32:40',
#  'latitude': '-36.3521',
#  'longitude': '142.2008',
#  'owner': 194,
#  'surface_temperature_celcius': 120}
#
#
# {'_id': 10876,
#  'confidence': 100,
#  'date': '4/05/2017',
#  'datetime': '2017-05-04T04:44:50',
#  'latitude': '-36.4057',
#  'longitude': '140.9806',
#  'owner': 224,
#  'surface_temperature_celcius': 119}

# %% [markdown]
# ###### Task f: Number of fire in each day. You are required to only display the total number of fire and the date in the output.

# %%
result=db['hotspot_historic'].aggregate([
    {"$group":    {"_id":"$date", "count": {"$sum":1}}}])
#     find("date").count()
                                                           
for document in result: 
    pprint(document)
# Out:
# {'_id': '6/03/2017', 'count': 2}
# {'_id': '7/03/2017', 'count': 1}
# {'_id': '9/03/2017', 'count': 3}
# {'_id': '12/03/2017', 'count': 5}
# {'_id': '13/03/2017', 'count': 2}
# {'_id': '14/03/2017', 'count': 10}
# {'_id': '18/03/2017', 'count': 3}
# {'_id': '19/03/2017', 'count': 21}
# {'_id': '28/03/2017', 'count': 54}
# {'_id': '29/03/2017', 'count': 1}
# {'_id': '31/03/2017', 'count': 22}
# {'_id': '2/04/2017', 'count': 5}
# {'_id': '4/04/2017', 'count': 89}
# {'_id': '5/04/2017', 'count': 49}
# {'_id': '7/04/2017', 'count': 39}
# {'_id': '15/04/2017', 'count': 69}
# {'_id': '17/04/2017', 'count': 38}
# {'_id': '18/04/2017', 'count': 325}
# {'_id': '19/04/2017', 'count': 50}
# {'_id': '20/04/2017', 'count': 31}
# {'_id': '23/04/2017', 'count': 19}
# {'_id': '24/04/2017', 'count': 8}
# {'_id': '25/04/2017', 'count': 3}
# {'_id': '26/04/2017', 'count': 1}
# {'_id': '29/04/2017', 'count': 3}
# {'_id': '4/05/2017', 'count': 135}
# {'_id': '3/04/2017', 'count': 72}
# {'_id': '6/05/2017', 'count': 17}
# {'_id': '7/05/2017', 'count': 3}
# {'_id': '22/06/2017', 'count': 1}
# {'_id': '25/03/2017', 'count': 13}
# {'_id': '8/10/2017', 'count': 1}
# {'_id': '10/08/2017', 'count': 1}
# {'_id': '9/10/2017', 'count': 1}
# {'_id': '15/10/2017', 'count': 3}
# {'_id': '16/10/2017', 'count': 1}
# {'_id': '3/05/2017', 'count': 64}
# {'_id': '27/09/2017', 'count': 7}
# {'_id': '10/10/2017', 'count': 3}
# {'_id': '14/04/2017', 'count': 18}
# {'_id': '2/06/2017', 'count': 11}
# {'_id': '26/10/2017', 'count': 5}
# {'_id': '6/10/2017', 'count': 2}
# {'_id': '20/10/2017', 'count': 3}
# {'_id': '2/10/2017', 'count': 7}
# {'_id': '21/11/2017', 'count': 1}
# {'_id': '16/12/2017', 'count': 15}
# {'_id': '18/10/2017', 'count': 6}
# {'_id': '7/10/2017', 'count': 1}
# {'_id': '21/09/2017', 'count': 2}
# {'_id': '31/07/2017', 'count': 2}
# {'_id': '8/11/2017', 'count': 2}
# {'_id': '10/09/2017', 'count': 4}
# {'_id': '20/06/2017', 'count': 6}
# {'_id': '5/11/2017', 'count': 4}
# {'_id': '22/09/2017', 'count': 1}
# {'_id': '8/03/2017', 'count': 2}
# {'_id': '11/04/2017', 'count': 24}
# {'_id': '12/12/2017', 'count': 1}
# {'_id': '27/12/2017', 'count': 4}
# {'_id': '2/05/2017', 'count': 10}
# {'_id': '13/11/2017', 'count': 5}
# {'_id': '23/11/2017', 'count': 5}
# {'_id': '1/06/2017', 'count': 2}
# {'_id': '23/05/2017', 'count': 5}
# {'_id': '12/04/2017', 'count': 69}
# {'_id': '3/10/2017', 'count': 18}
# {'_id': '24/05/2017', 'count': 3}
# {'_id': '17/10/2017', 'count': 5}
# {'_id': '15/12/2017', 'count': 4}
# {'_id': '4/06/2017', 'count': 9}
# {'_id': '12/11/2017', 'count': 5}
# {'_id': '11/06/2017', 'count': 2}
# {'_id': '2/08/2017', 'count': 2}
# {'_id': '14/12/2017', 'count': 1}
# {'_id': '14/08/2017', 'count': 5}
# {'_id': '14/07/2017', 'count': 2}
# {'_id': '14/11/2017', 'count': 3}
# {'_id': '25/12/2017', 'count': 1}
# {'_id': '1/10/2017', 'count': 8}
# {'_id': '9/12/2017', 'count': 4}
# {'_id': '11/11/2017', 'count': 4}
# {'_id': '5/05/2017', 'count': 31}
# {'_id': '13/12/2017', 'count': 1}
# {'_id': '27/10/2017', 'count': 5}
# {'_id': '10/12/2017', 'count': 2}
# {'_id': '10/03/2017', 'count': 8}
# {'_id': '5/07/2017', 'count': 1}
# {'_id': '6/04/2017', 'count': 118}
# {'_id': '14/06/2017', 'count': 4}
# {'_id': '26/03/2017', 'count': 17}
# {'_id': '29/09/2017', 'count': 2}
# {'_id': '17/03/2017', 'count': 6}
# {'_id': '2/07/2017', 'count': 8}
# {'_id': '13/05/2017', 'count': 54}
# {'_id': '4/10/2017', 'count': 5}
# {'_id': '30/11/2017', 'count': 31}
# {'_id': '16/04/2017', 'count': 18}
# {'_id': '18/05/2017', 'count': 7}
# {'_id': '28/10/2017', 'count': 1}
# {'_id': '29/11/2017', 'count': 8}
# {'_id': '1/04/2017', 'count': 7}
# {'_id': '28/11/2017', 'count': 1}
# {'_id': '23/09/2017', 'count': 23}
# {'_id': '23/10/2017', 'count': 1}
# {'_id': '9/11/2017', 'count': 10}
# {'_id': '22/11/2017', 'count': 2}
# {'_id': '26/09/2017', 'count': 1}
# {'_id': '21/12/2017', 'count': 1}
# {'_id': '13/06/2017', 'count': 1}
# {'_id': '24/09/2017', 'count': 28}
# {'_id': '24/12/2017', 'count': 1}
# {'_id': '20/09/2017', 'count': 5}
# {'_id': '21/10/2017', 'count': 4}
# {'_id': '13/08/2017', 'count': 9}
# {'_id': '18/06/2017', 'count': 2}
# {'_id': '5/08/2017', 'count': 1}
# {'_id': '1/08/2017', 'count': 2}
# {'_id': '1/05/2017', 'count': 20}
# {'_id': '10/05/2017', 'count': 114}
# {'_id': '8/04/2017', 'count': 20}
# {'_id': '6/07/2017', 'count': 3}
# {'_id': '4/07/2017', 'count': 1}
# {'_id': '8/12/2017', 'count': 5}
# {'_id': '1/07/2017', 'count': 4}
# {'_id': '29/07/2017', 'count': 2}
# {'_id': '30/06/2017', 'count': 6}
# {'_id': '13/04/2017', 'count': 357}
# {'_id': '8/05/2017', 'count': 24}
# {'_id': '16/06/2017', 'count': 2}
# {'_id': '15/03/2017', 'count': 7}
# {'_id': '17/05/2017', 'count': 1}
# {'_id': '16/05/2017', 'count': 3}
# {'_id': '9/06/2017', 'count': 3}
# {'_id': '7/06/2017', 'count': 14}
# {'_id': '3/06/2017', 'count': 2}
# {'_id': '24/03/2017', 'count': 2}
# {'_id': '26/05/2017', 'count': 4}
# {'_id': '22/05/2017', 'count': 33}
# {'_id': '15/05/2017', 'count': 102}
# {'_id': '14/05/2017', 'count': 1}
# {'_id': '12/05/2017', 'count': 10}
# {'_id': '11/05/2017', 'count': 19}
# {'_id': '22/04/2017', 'count': 2}
# {'_id': '9/05/2017', 'count': 13}

# %% [markdown]
# ###### Task g: Average surface temperature (°C) for each day.
# (displaying average surface temperature (°C) and the date in the output.)

# %%
result=db['hotspot_historic'].aggregate([
    {"$group":    {"_id":"$date", "Average Temprature on the day": {"$avg":"$surface_temperature_celcius"}}}])
#     find("date").count()
                                                           
for document in result: 
    pprint(document)
# Out:
# {'Average Temprature on the day': 60.5, '_id': '6/03/2017'}
# {'Average Temprature on the day': 64.0, '_id': '7/03/2017'}
# {'Average Temprature on the day': 46.666666666666664, '_id': '9/03/2017'}
# {'Average Temprature on the day': 88.2, '_id': '12/03/2017'}
# {'Average Temprature on the day': 38.5, '_id': '13/03/2017'}
# {'Average Temprature on the day': 65.6, '_id': '14/03/2017'}
# {'Average Temprature on the day': 79.33333333333333, '_id': '18/03/2017'}
# {'Average Temprature on the day': 65.57142857142857, '_id': '19/03/2017'}
# {'Average Temprature on the day': 60.925925925925924, '_id': '28/03/2017'}
# {'Average Temprature on the day': 51.0, '_id': '29/03/2017'}
# {'Average Temprature on the day': 48.72727272727273, '_id': '31/03/2017'}
# {'Average Temprature on the day': 45.2, '_id': '2/04/2017'}
# {'Average Temprature on the day': 62.57303370786517, '_id': '4/04/2017'}
# {'Average Temprature on the day': 53.142857142857146, '_id': '5/04/2017'}
# {'Average Temprature on the day': 50.69230769230769, '_id': '7/04/2017'}
# {'Average Temprature on the day': 59.57971014492754, '_id': '15/04/2017'}
# {'Average Temprature on the day': 50.921052631578945, '_id': '17/04/2017'}
# {'Average Temprature on the day': 53.36615384615384, '_id': '18/04/2017'}
# {'Average Temprature on the day': 54.16, '_id': '19/04/2017'}
# {'Average Temprature on the day': 56.58064516129032, '_id': '20/04/2017'}
# {'Average Temprature on the day': 53.89473684210526, '_id': '23/04/2017'}
# {'Average Temprature on the day': 59.375, '_id': '24/04/2017'}
# {'Average Temprature on the day': 48.666666666666664, '_id': '25/04/2017'}
# {'Average Temprature on the day': 34.0, '_id': '26/04/2017'}
# {'Average Temprature on the day': 63.0, '_id': '29/04/2017'}
# {'Average Temprature on the day': 56.80740740740741, '_id': '4/05/2017'}
# {'Average Temprature on the day': 58.44444444444444, '_id': '3/04/2017'}
# {'Average Temprature on the day': 57.529411764705884, '_id': '6/05/2017'}
# {'Average Temprature on the day': 50.333333333333336, '_id': '7/05/2017'}
# {'Average Temprature on the day': 46.0, '_id': '22/06/2017'}
# {'Average Temprature on the day': 66.0, '_id': '25/03/2017'}
# {'Average Temprature on the day': 41.0, '_id': '8/10/2017'}
# {'Average Temprature on the day': 63.0, '_id': '10/08/2017'}
# {'Average Temprature on the day': 44.0, '_id': '9/10/2017'}
# {'Average Temprature on the day': 72.66666666666667, '_id': '15/10/2017'}
# {'Average Temprature on the day': 36.0, '_id': '16/10/2017'}
# {'Average Temprature on the day': 56.796875, '_id': '3/05/2017'}
# {'Average Temprature on the day': 49.714285714285715, '_id': '27/09/2017'}
# {'Average Temprature on the day': 53.333333333333336, '_id': '10/10/2017'}
# {'Average Temprature on the day': 61.94444444444444, '_id': '14/04/2017'}
# {'Average Temprature on the day': 47.72727272727273, '_id': '2/06/2017'}
# {'Average Temprature on the day': 44.6, '_id': '26/10/2017'}
# {'Average Temprature on the day': 44.0, '_id': '6/10/2017'}
# {'Average Temprature on the day': 50.0, '_id': '20/10/2017'}
# {'Average Temprature on the day': 43.57142857142857, '_id': '2/10/2017'}
# {'Average Temprature on the day': 59.0, '_id': '21/11/2017'}
# {'Average Temprature on the day': 57.8, '_id': '16/12/2017'}
# {'Average Temprature on the day': 52.166666666666664, '_id': '18/10/2017'}
# {'Average Temprature on the day': 42.0, '_id': '7/10/2017'}
# {'Average Temprature on the day': 40.5, '_id': '21/09/2017'}
# {'Average Temprature on the day': 47.0, '_id': '31/07/2017'}
# {'Average Temprature on the day': 45.5, '_id': '8/11/2017'}
# {'Average Temprature on the day': 56.5, '_id': '10/09/2017'}
# {'Average Temprature on the day': 71.16666666666667, '_id': '20/06/2017'}
# {'Average Temprature on the day': 58.5, '_id': '5/11/2017'}
# {'Average Temprature on the day': 45.0, '_id': '22/09/2017'}
# {'Average Temprature on the day': 51.5, '_id': '8/03/2017'}
# {'Average Temprature on the day': 46.291666666666664, '_id': '11/04/2017'}
# {'Average Temprature on the day': 44.0, '_id': '12/12/2017'}
# {'Average Temprature on the day': 62.75, '_id': '27/12/2017'}
# {'Average Temprature on the day': 55.6, '_id': '2/05/2017'}
# {'Average Temprature on the day': 47.0, '_id': '13/11/2017'}
# {'Average Temprature on the day': 58.8, '_id': '23/11/2017'}
# {'Average Temprature on the day': 54.0, '_id': '1/06/2017'}
# {'Average Temprature on the day': 51.2, '_id': '23/05/2017'}
# {'Average Temprature on the day': 52.69565217391305, '_id': '12/04/2017'}
# {'Average Temprature on the day': 50.0, '_id': '3/10/2017'}
# {'Average Temprature on the day': 40.333333333333336, '_id': '24/05/2017'}
# {'Average Temprature on the day': 51.6, '_id': '17/10/2017'}
# {'Average Temprature on the day': 39.0, '_id': '15/12/2017'}
# {'Average Temprature on the day': 52.22222222222222, '_id': '4/06/2017'}
# {'Average Temprature on the day': 53.0, '_id': '12/11/2017'}
# {'Average Temprature on the day': 41.5, '_id': '11/06/2017'}
# {'Average Temprature on the day': 63.5, '_id': '2/08/2017'}
# {'Average Temprature on the day': 70.0, '_id': '14/12/2017'}
# {'Average Temprature on the day': 40.8, '_id': '14/08/2017'}
# {'Average Temprature on the day': 41.5, '_id': '14/07/2017'}
# {'Average Temprature on the day': 52.0, '_id': '14/11/2017'}
# {'Average Temprature on the day': 54.0, '_id': '25/12/2017'}
# {'Average Temprature on the day': 48.25, '_id': '1/10/2017'}
# {'Average Temprature on the day': 58.25, '_id': '9/12/2017'}
# {'Average Temprature on the day': 46.25, '_id': '11/11/2017'}
# {'Average Temprature on the day': 51.70967741935484, '_id': '5/05/2017'}
# {'Average Temprature on the day': 60.0, '_id': '13/12/2017'}
# {'Average Temprature on the day': 50.4, '_id': '27/10/2017'}
# {'Average Temprature on the day': 46.0, '_id': '10/12/2017'}
# {'Average Temprature on the day': 69.375, '_id': '10/03/2017'}
# {'Average Temprature on the day': 45.0, '_id': '5/07/2017'}
# {'Average Temprature on the day': 61.71186440677966, '_id': '6/04/2017'}
# {'Average Temprature on the day': 53.25, '_id': '14/06/2017'}
# {'Average Temprature on the day': 56.88235294117647, '_id': '26/03/2017'}
# {'Average Temprature on the day': 43.0, '_id': '29/09/2017'}
# {'Average Temprature on the day': 59.5, '_id': '17/03/2017'}
# {'Average Temprature on the day': 43.5, '_id': '2/07/2017'}
# {'Average Temprature on the day': 58.611111111111114, '_id': '13/05/2017'}
# {'Average Temprature on the day': 49.0, '_id': '4/10/2017'}
# {'Average Temprature on the day': 52.41935483870968, '_id': '30/11/2017'}
# {'Average Temprature on the day': 48.72222222222222, '_id': '16/04/2017'}
# {'Average Temprature on the day': 44.142857142857146, '_id': '18/05/2017'}
# {'Average Temprature on the day': 56.0, '_id': '28/10/2017'}
# {'Average Temprature on the day': 60.625, '_id': '29/11/2017'}
# {'Average Temprature on the day': 46.714285714285715, '_id': '1/04/2017'}
# {'Average Temprature on the day': 42.0, '_id': '28/11/2017'}
# {'Average Temprature on the day': 52.73913043478261, '_id': '23/09/2017'}
# {'Average Temprature on the day': 38.0, '_id': '23/10/2017'}
# {'Average Temprature on the day': 61.3, '_id': '9/11/2017'}
# {'Average Temprature on the day': 61.5, '_id': '22/11/2017'}
# {'Average Temprature on the day': 33.0, '_id': '26/09/2017'}
# {'Average Temprature on the day': 46.0, '_id': '21/12/2017'}
# {'Average Temprature on the day': 41.0, '_id': '13/06/2017'}
# {'Average Temprature on the day': 53.57142857142857, '_id': '24/09/2017'}
# {'Average Temprature on the day': 32.0, '_id': '24/12/2017'}
# {'Average Temprature on the day': 63.6, '_id': '20/09/2017'}
# {'Average Temprature on the day': 51.25, '_id': '21/10/2017'}
# {'Average Temprature on the day': 49.0, '_id': '13/08/2017'}
# {'Average Temprature on the day': 42.0, '_id': '18/06/2017'}
# {'Average Temprature on the day': 40.0, '_id': '5/08/2017'}
# {'Average Temprature on the day': 58.0, '_id': '1/08/2017'}
# {'Average Temprature on the day': 68.4, '_id': '1/05/2017'}
# {'Average Temprature on the day': 52.86842105263158, '_id': '10/05/2017'}
# {'Average Temprature on the day': 60.75, '_id': '8/04/2017'}
# {'Average Temprature on the day': 56.0, '_id': '6/07/2017'}
# {'Average Temprature on the day': 40.0, '_id': '4/07/2017'}
# {'Average Temprature on the day': 50.6, '_id': '8/12/2017'}
# {'Average Temprature on the day': 30.5, '_id': '1/07/2017'}
# {'Average Temprature on the day': 48.0, '_id': '29/07/2017'}
# {'Average Temprature on the day': 44.333333333333336, '_id': '30/06/2017'}
# {'Average Temprature on the day': 58.57983193277311, '_id': '13/04/2017'}
# {'Average Temprature on the day': 56.291666666666664, '_id': '8/05/2017'}
# {'Average Temprature on the day': 42.5, '_id': '16/06/2017'}
# {'Average Temprature on the day': 46.0, '_id': '15/03/2017'}
# {'Average Temprature on the day': 52.0, '_id': '17/05/2017'}
# {'Average Temprature on the day': 39.666666666666664, '_id': '16/05/2017'}
# {'Average Temprature on the day': 49.0, '_id': '9/06/2017'}
# {'Average Temprature on the day': 51.857142857142854, '_id': '7/06/2017'}
# {'Average Temprature on the day': 47.0, '_id': '3/06/2017'}
# {'Average Temprature on the day': 49.0, '_id': '24/03/2017'}
# {'Average Temprature on the day': 49.5, '_id': '26/05/2017'}
# {'Average Temprature on the day': 54.484848484848484, '_id': '22/05/2017'}
# {'Average Temprature on the day': 53.950980392156865, '_id': '15/05/2017'}
# {'Average Temprature on the day': 49.0, '_id': '14/05/2017'}
# {'Average Temprature on the day': 51.5, '_id': '12/05/2017'}
# {'Average Temprature on the day': 59.36842105263158, '_id': '11/05/2017'}
# {'Average Temprature on the day': 54.5, '_id': '22/04/2017'}
# {'Average Temprature on the day': 42.46153846153846, '_id': '9/05/2017'}
